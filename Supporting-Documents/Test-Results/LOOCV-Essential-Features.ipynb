# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import random
import tensorflow as tf
from sklearn.metrics import classification_report
from sklearn import metrics
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Conv1D, Dropout, MaxPooling1D, BatchNormalization
from keras.utils import plot_model

# %% [markdown]
# Run subject_segregation.py and check-subject-validity.py prior to this.

# %%
#Create uun list for testing, training and validation

random.seed(100)
src_folder = 'processed-data/'

uun_list = [s for s in os.listdir(src_folder) if s[0]== 's']
uun_list = random.sample(uun_list,len(uun_list))

print("Total size of list: " + str(len(uun_list)))
# Out:
# Total size of list: 78

# %%
def create_dataFrame(uun_list, df_name, src_folder):
    base_df = pd.DataFrame()

    for uun in uun_list:
      files_per_uun = [s for s in os.listdir(os.path.join(src_folder,uun))]
        
      for file in files_per_uun:
          # load data into a DataFrame 
          path = os.path.join(src_folder, uun, file)
          new_df = pd.read_csv(path)
          # merge into the base DataFrame 
          base_df = pd.concat([base_df, new_df])
            
    base_df.reset_index(drop=True, inplace=True)
    base_df.drop(base_df[base_df['sensor_type'] == "Thingy"].index, inplace = True)
    
    print(f"Data from: {df_name}")
    print(f"The data was collected using the sensors: {base_df.sensor_type.unique()}")
    print(f"The data was collected for the activities: {base_df.activity_type.unique()}")
    print(f"The number of activities collected: {len(base_df.activity_type.unique())}")
    print(f"The number of unique recordings is: {len(base_df.recording_id.unique())}")
    print(f"The subject IDs in the recordings are: {len(base_df.subject_id.unique())}")
    print("\n")
            
    return base_df

def clean_dataFrame(df):
    df.drop('notes', axis=1, inplace=True)
    df.drop('sensor_type', axis=1, inplace=True)
    df.drop('subject_id', axis=1, inplace=True)
    df.drop('activity_code', axis=1, inplace=True)
    df.dropna(inplace=True)
    
def get_sliding_windows(df):
    recording_id_list = df.recording_id.unique()
    sliding_windows = pd.DataFrame()
    window_size = 50 # 50 datapoints for the window size, which, at 25Hz, means 2 seconds
    step_size = 25 # this is 50% overlap

    window_number = 0 # start a counter at 0 to keep track of the window number

    for recording in recording_id_list:
        current_window = df.loc[df['recording_id'] == recording]
        large_enough_windows = [window for window in current_window.rolling(window=window_size, min_periods=window_size) if len(window) == window_size]
        overlapping_windows = large_enough_windows[::step_size] 

        for window in overlapping_windows:
            window.loc[:, 'window_id'] = window_number
            window_number += 1

        final_sliding_windows = pd.concat(overlapping_windows)
        sliding_windows = pd.concat([sliding_windows, final_sliding_windows])

    sliding_windows.reset_index(drop=True, inplace=True)
    return sliding_windows

def model_data(df_sliding_windows):
    X = []
    y = []

    for window_id, group in df_sliding_windows.groupby('window_id'):

        shape = group[columns_of_interest].values.shape
        
        X.append(group[columns_of_interest].values)
        y.append(class_labels[group["activity_type"].values[0]])
        
    X = np.asarray(X)
    y = np.asarray(pd.get_dummies(np.asarray(y)), dtype=np.float32)
    return (X,y)

def get_model_input(df):
    clean_dataFrame(df)
    df.drop(df[df['activity_type'] == "Climbing stairs"].index, inplace = True)
    df.drop(df[df['activity_type'] == "Descending stairs"].index, inplace = True)
    df.drop(df[df['activity_type'] == "Movement"].index, inplace = True)

    df['activity_type'] = df['activity_type'].replace(['Sitting', 'Sitting bent forward', 'Sitting bent backward', 'Standing', 'Desk work'], 'Sitting/Standing')
    df['activity_type'] = df['activity_type'].replace(['Lying down right', 'Lying down left', 'Lying down on back', 'Lying down on stomach'], 'Lying down')

    return model_data(get_sliding_windows(df))

def create_model():
    filters = 64
    kernel_size = 3
    n_features = 6
    activation='relu'
    n_classes = 4
    window_size = 50

    model = Sequential()
    model.add(Conv1D(filters=filters, kernel_size=kernel_size, activation='linear', 
                    input_shape=(window_size, n_features)))
    model.add(BatchNormalization())
    model.add(Activation(activation))

    model.add(Conv1D(filters=filters, kernel_size=kernel_size, activation='linear'))
    model.add(BatchNormalization())
    model.add(Activation(activation))

    model.add(Conv1D(filters=filters, kernel_size=kernel_size, activation='linear'))
    model.add(BatchNormalization())
    model.add(Activation(activation))

    model.add(Conv1D(filters=filters, kernel_size=kernel_size, activation='linear'))
    model.add(BatchNormalization())
    model.add(Activation(activation))

    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(n_classes, activation='softmax'))

    model.summary()
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics = ['accuracy'])

    return model

# %%
columns_of_interest = ['accel_x', 'accel_y', 'accel_z', 'gyro_x', 'gyro_y', 'gyro_z']

class_labels = {
    'Sitting/Standing' : 0,
    'Walking at normal speed' : 1,
    'Lying down' : 2,
    'Running' : 3
}

# %%
accuracies = []

for x in range(len(uun_list)):
    current_list = ['s1892493','s1852056', 's2303866', 's2255740', 's1977764', 's1828233', 's1908422', 's1842855', 's1837624', 's1965695', 's2342658', 's1900673', 's1973139', 's1904845', 's1915425', 's1921856', 's1957945', 's1962038', 's2269664', 's2303353', 's1925182', 's1923493', 's1858629', 's1992413', 's2308859', 's1732873', 's1974565', 's1957847', 's1826377', 's1998909', 's1817967', 's1918275', 's1832137', 's1839825', 's1926989', 's1853226', 's2298733', 's1961351', 's1863792', 's1800600', 's1901843', 's1912558', 's1911027', 's1948094', 's1941321', 's1967984', 's1836526', 's1956488', 's1912614', 's2299270', 's1834237', 's1951735', 's1800825', 's1911455', 's1973235', 's1918258', 's1862671', 's1810150', 's1910268', 's1931698', 's1931736', 's1832512', 's1925715', 's1960578', 's1909083', 's1925709', 's1976098', 's1912575', 's1927811', 's1809887', 's1923449', 's1951693', 's1967087', 's1996403', 's1935680', 's1925695', 's1920337', 's1862323']
    testing_df = create_dataFrame([current_list[x],], "Testing DF", src_folder)
    del current_list[x]
    training_df = create_dataFrame(current_list, "Training DF", src_folder)

    (X_train, y_train) = get_model_input(training_df)
    (X_test, y_test) = get_model_input(testing_df)

    model = create_model()
    model.fit(X_train, y_train, batch_size=32, epochs=7)
    (_, accuracy) = model.evaluate(X_test, y_test)
    accuracies.append(accuracy * 100.0)
    
    print( str(x + 1) + " Iteration completed.")
    print("Accuracy of " + str(accuracy * 100.0) + " achieved.")
# Out:
# Data from: Testing DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Desk work' 'Sitting' 'Movement' 'Running' 'Standing'
#  'Sitting bent backward' 'Descending stairs' 'Lying down right'
#  'Lying down on stomach' 'Lying down on back' 'Sitting bent forward'
#  'Climbing stairs' 'Walking at normal speed' 'Lying down left']
# The number of activities collected: 14
# The number of unique recordings is: 14
# The subject IDs in the recordings are: 1
#
#
# Data from: Training DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Walking at normal speed' 'Desk work' 'Sitting' 'Lying down on back'
#  'Climbing stairs' 'Standing' 'Movement' 'Lying down left'
#  'Sitting bent backward' 'Descending stairs' 'Running'
#  'Sitting bent forward' 'Lying down right' 'Lying down on stomach']
# The number of activities collected: 14
# The number of unique recordings is: 1077
# The subject IDs in the recordings are: 78
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# Streaming output truncated to the last 5000 lines.
#  'Movement' 'Descending stairs' 'Lying down on stomach'
#  'Lying down on back' 'Sitting bent backward' 'Running']
# The number of activities collected: 14
# The number of unique recordings is: 14
# The subject IDs in the recordings are: 1
#
#
# Data from: Training DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Desk work' 'Sitting' 'Movement' 'Running' 'Standing'
#  'Sitting bent backward' 'Descending stairs' 'Lying down right'
#  'Lying down on stomach' 'Lying down on back' 'Sitting bent forward'
#  'Climbing stairs' 'Walking at normal speed' 'Lying down left']
# The number of activities collected: 14
# The number of unique recordings is: 1077
# The subject IDs in the recordings are: 78
#
#
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_68 (Conv1D)          (None, 48, 64)            1216
#
#  batch_normalization_68 (Bat  (None, 48, 64)           256
#  chNormalization)
#
#  activation_68 (Activation)  (None, 48, 64)            0
#
#  conv1d_69 (Conv1D)          (None, 46, 64)            12352
#
#  batch_normalization_69 (Bat  (None, 46, 64)           256
#  chNormalization)
#
#  activation_69 (Activation)  (None, 46, 64)            0
#
#  conv1d_70 (Conv1D)          (None, 44, 64)            12352
#
#  batch_normalization_70 (Bat  (None, 44, 64)           256
#  chNormalization)
#
#  activation_70 (Activation)  (None, 44, 64)            0
#
#  conv1d_71 (Conv1D)          (None, 42, 64)            12352
#
#  batch_normalization_71 (Bat  (None, 42, 64)           256
#  chNormalization)
#
#  activation_71 (Activation)  (None, 42, 64)            0
#
#  flatten_17 (Flatten)        (None, 2688)              0
#
#  dense_34 (Dense)            (None, 100)               268900
#
#  dense_35 (Dense)            (None, 4)                 404
#
# =================================================================
# Total params: 308,600
# Trainable params: 308,088
# Non-trainable params: 512
# _________________________________________________________________
# Epoch 1/7
# 771/771 [==============================] - 7s 8ms/step - loss: 0.1538 - accuracy: 0.9465
# Epoch 2/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0679 - accuracy: 0.9773
# Epoch 3/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0617 - accuracy: 0.9788
# Epoch 4/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0514 - accuracy: 0.9817
# Epoch 5/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0425 - accuracy: 0.9849
# Epoch 6/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0417 - accuracy: 0.9852
# Epoch 7/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0377 - accuracy: 0.9868
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0414 - accuracy: 0.9938
# 18 Iteration completed.
# Accuracy of 99.38271641731262 achieved.
# Data from: Testing DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Movement' 'Climbing stairs' 'Lying down left' 'Walking at normal speed'
#  'Lying down on back' 'Desk work' 'Sitting bent backward' 'Standing'
#  'Sitting bent forward' 'Sitting' 'Running' 'Lying down right'
#  'Lying down on stomach' 'Descending stairs']
# The number of activities collected: 14
# The number of unique recordings is: 14
# The subject IDs in the recordings are: 1
#
#
# Data from: Training DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Desk work' 'Sitting' 'Movement' 'Running' 'Standing'
#  'Sitting bent backward' 'Descending stairs' 'Lying down right'
#  'Lying down on stomach' 'Lying down on back' 'Sitting bent forward'
#  'Climbing stairs' 'Walking at normal speed' 'Lying down left']
# The number of activities collected: 14
# The number of unique recordings is: 1077
# The subject IDs in the recordings are: 78
#
#
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_72 (Conv1D)          (None, 48, 64)            1216
#
#  batch_normalization_72 (Bat  (None, 48, 64)           256
#  chNormalization)
#
#  activation_72 (Activation)  (None, 48, 64)            0
#
#  conv1d_73 (Conv1D)          (None, 46, 64)            12352
#
#  batch_normalization_73 (Bat  (None, 46, 64)           256
#  chNormalization)
#
#  activation_73 (Activation)  (None, 46, 64)            0
#
#  conv1d_74 (Conv1D)          (None, 44, 64)            12352
#
#  batch_normalization_74 (Bat  (None, 44, 64)           256
#  chNormalization)
#
#  activation_74 (Activation)  (None, 44, 64)            0
#
#  conv1d_75 (Conv1D)          (None, 42, 64)            12352
#
#  batch_normalization_75 (Bat  (None, 42, 64)           256
#  chNormalization)
#
#  activation_75 (Activation)  (None, 42, 64)            0
#
#  flatten_18 (Flatten)        (None, 2688)              0
#
#  dense_36 (Dense)            (None, 100)               268900
#
#  dense_37 (Dense)            (None, 4)                 404
#
# =================================================================
# Total params: 308,600
# Trainable params: 308,088
# Non-trainable params: 512
# _________________________________________________________________
# Epoch 1/7
# 771/771 [==============================] - 7s 8ms/step - loss: 0.1584 - accuracy: 0.9489
# Epoch 2/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0765 - accuracy: 0.9725
# Epoch 3/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0675 - accuracy: 0.9764
# Epoch 4/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0515 - accuracy: 0.9823
# Epoch 5/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0624 - accuracy: 0.9780
# Epoch 6/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0437 - accuracy: 0.9857
# Epoch 7/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0397 - accuracy: 0.9860
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0108 - accuracy: 1.0000
# 19 Iteration completed.
# Accuracy of 100.0 achieved.
# Data from: Testing DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Lying down on back' 'Running' 'Movement' 'Descending stairs'
#  'Walking at normal speed' 'Lying down on stomach' 'Desk work' 'Standing'
#  'Lying down right' 'Sitting bent forward' 'Sitting bent backward'
#  'Sitting' 'Lying down left' 'Climbing stairs']
# The number of activities collected: 14
# The number of unique recordings is: 14
# The subject IDs in the recordings are: 1
#
#
# Data from: Training DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Desk work' 'Sitting' 'Movement' 'Running' 'Standing'
#  'Sitting bent backward' 'Descending stairs' 'Lying down right'
#  'Lying down on stomach' 'Lying down on back' 'Sitting bent forward'
#  'Climbing stairs' 'Walking at normal speed' 'Lying down left']
# The number of activities collected: 14
# The number of unique recordings is: 1077
# The subject IDs in the recordings are: 78
#
#
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_76 (Conv1D)          (None, 48, 64)            1216
#
#  batch_normalization_76 (Bat  (None, 48, 64)           256
#  chNormalization)
#
#  activation_76 (Activation)  (None, 48, 64)            0
#
#  conv1d_77 (Conv1D)          (None, 46, 64)            12352
#
#  batch_normalization_77 (Bat  (None, 46, 64)           256
#  chNormalization)
#
#  activation_77 (Activation)  (None, 46, 64)            0
#
#  conv1d_78 (Conv1D)          (None, 44, 64)            12352
#
#  batch_normalization_78 (Bat  (None, 44, 64)           256
#  chNormalization)
#
#  activation_78 (Activation)  (None, 44, 64)            0
#
#  conv1d_79 (Conv1D)          (None, 42, 64)            12352
#
#  batch_normalization_79 (Bat  (None, 42, 64)           256
#  chNormalization)
#
#  activation_79 (Activation)  (None, 42, 64)            0
#
#  flatten_19 (Flatten)        (None, 2688)              0
#
#  dense_38 (Dense)            (None, 100)               268900
#
#  dense_39 (Dense)            (None, 4)                 404
#
# =================================================================
# Total params: 308,600
# Trainable params: 308,088
# Non-trainable params: 512
# _________________________________________________________________
# Epoch 1/7
# 770/770 [==============================] - 7s 8ms/step - loss: 0.1589 - accuracy: 0.9488
# Epoch 2/7
# 770/770 [==============================] - 6s 8ms/step - loss: 0.0783 - accuracy: 0.9725
# Epoch 3/7
# 770/770 [==============================] - 6s 8ms/step - loss: 0.0670 - accuracy: 0.9766
# Epoch 4/7
# 770/770 [==============================] - 6s 8ms/step - loss: 0.0567 - accuracy: 0.9799
# Epoch 5/7
# 770/770 [==============================] - 6s 8ms/step - loss: 0.0560 - accuracy: 0.9829
# Epoch 6/7
# 770/770 [==============================] - 7s 9ms/step - loss: 0.0433 - accuracy: 0.9850
# Epoch 7/7
# 770/770 [==============================] - 6s 8ms/step - loss: 0.0473 - accuracy: 0.9836
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0114 - accuracy: 1.0000
# 20 Iteration completed.
# Accuracy of 100.0 achieved.
# Data from: Testing DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Walking at normal speed' 'Lying down on stomach' 'Lying down right'
#  'Sitting' 'Desk work' 'Standing' 'Sitting bent backward'
#  'Lying down left' 'Running' 'Descending stairs' 'Lying down on back'
#  'Sitting bent forward' 'Movement' 'Climbing stairs']
# The number of activities collected: 14
# The number of unique recordings is: 14
# The subject IDs in the recordings are: 1
#
#
# Data from: Training DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Desk work' 'Sitting' 'Movement' 'Running' 'Standing'
#  'Sitting bent backward' 'Descending stairs' 'Lying down right'
#  'Lying down on stomach' 'Lying down on back' 'Sitting bent forward'
#  'Climbing stairs' 'Walking at normal speed' 'Lying down left']
# The number of activities collected: 14
# The number of unique recordings is: 1077
# The subject IDs in the recordings are: 78
#
#
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_80 (Conv1D)          (None, 48, 64)            1216
#
#  batch_normalization_80 (Bat  (None, 48, 64)           256
#  chNormalization)
#
#  activation_80 (Activation)  (None, 48, 64)            0
#
#  conv1d_81 (Conv1D)          (None, 46, 64)            12352
#
#  batch_normalization_81 (Bat  (None, 46, 64)           256
#  chNormalization)
#
#  activation_81 (Activation)  (None, 46, 64)            0
#
#  conv1d_82 (Conv1D)          (None, 44, 64)            12352
#
#  batch_normalization_82 (Bat  (None, 44, 64)           256
#  chNormalization)
#
#  activation_82 (Activation)  (None, 44, 64)            0
#
#  conv1d_83 (Conv1D)          (None, 42, 64)            12352
#
#  batch_normalization_83 (Bat  (None, 42, 64)           256
#  chNormalization)
#
#  activation_83 (Activation)  (None, 42, 64)            0
#
#  flatten_20 (Flatten)        (None, 2688)              0
#
#  dense_40 (Dense)            (None, 100)               268900
#
#  dense_41 (Dense)            (None, 4)                 404
#
# =================================================================
# Total params: 308,600
# Trainable params: 308,088
# Non-trainable params: 512
# _________________________________________________________________
# Epoch 1/7
# 771/771 [==============================] - 7s 8ms/step - loss: 0.1520 - accuracy: 0.9496
# Epoch 2/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0776 - accuracy: 0.9756
# Epoch 3/7
# 771/771 [==============================] - 7s 9ms/step - loss: 0.0617 - accuracy: 0.9785
# Epoch 4/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0630 - accuracy: 0.9785
# Epoch 5/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0496 - accuracy: 0.9828
# Epoch 6/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0458 - accuracy: 0.9831
# Epoch 7/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0423 - accuracy: 0.9852
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1367 - accuracy: 0.9221
# 21 Iteration completed.
# Accuracy of 92.21183657646179 achieved.
# Data from: Testing DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Movement' 'Descending stairs' 'Lying down left'
#  'Walking at normal speed' 'Lying down right' 'Desk work' 'Standing'
#  'Sitting bent backward' 'Sitting' 'Lying down on back' 'Running'
#  'Sitting bent forward' 'Climbing stairs' 'Lying down on stomach']
# The number of activities collected: 14
# The number of unique recordings is: 14
# The subject IDs in the recordings are: 1
#
#
# Data from: Training DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Desk work' 'Sitting' 'Movement' 'Running' 'Standing'
#  'Sitting bent backward' 'Descending stairs' 'Lying down right'
#  'Lying down on stomach' 'Lying down on back' 'Sitting bent forward'
#  'Climbing stairs' 'Walking at normal speed' 'Lying down left']
# The number of activities collected: 14
# The number of unique recordings is: 1077
# The subject IDs in the recordings are: 78
#
#
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_84 (Conv1D)          (None, 48, 64)            1216
#
#  batch_normalization_84 (Bat  (None, 48, 64)           256
#  chNormalization)
#
#  activation_84 (Activation)  (None, 48, 64)            0
#
#  conv1d_85 (Conv1D)          (None, 46, 64)            12352
#
#  batch_normalization_85 (Bat  (None, 46, 64)           256
#  chNormalization)
#
#  activation_85 (Activation)  (None, 46, 64)            0
#
#  conv1d_86 (Conv1D)          (None, 44, 64)            12352
#
#  batch_normalization_86 (Bat  (None, 44, 64)           256
#  chNormalization)
#
#  activation_86 (Activation)  (None, 44, 64)            0
#
#  conv1d_87 (Conv1D)          (None, 42, 64)            12352
#
#  batch_normalization_87 (Bat  (None, 42, 64)           256
#  chNormalization)
#
#  activation_87 (Activation)  (None, 42, 64)            0
#
#  flatten_21 (Flatten)        (None, 2688)              0
#
#  dense_42 (Dense)            (None, 100)               268900
#
#  dense_43 (Dense)            (None, 4)                 404
#
# =================================================================
# Total params: 308,600
# Trainable params: 308,088
# Non-trainable params: 512
# _________________________________________________________________
# Epoch 1/7
# 771/771 [==============================] - 7s 8ms/step - loss: 0.1484 - accuracy: 0.9490
# Epoch 2/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0712 - accuracy: 0.9755
# Epoch 3/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0664 - accuracy: 0.9780
# Epoch 4/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0535 - accuracy: 0.9813
# Epoch 5/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0494 - accuracy: 0.9821
# Epoch 6/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0413 - accuracy: 0.9858
# Epoch 7/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0363 - accuracy: 0.9869
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0084 - accuracy: 1.0000
# 22 Iteration completed.
# Accuracy of 100.0 achieved.
# Data from: Testing DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Sitting' 'Sitting bent forward' 'Sitting bent backward'
#  'Walking at normal speed' 'Standing' 'Lying down left' 'Desk work'
#  'Lying down on back' 'Running' 'Lying down right' 'Climbing stairs'
#  'Lying down on stomach' 'Descending stairs' 'Movement']
# The number of activities collected: 14
# The number of unique recordings is: 14
# The subject IDs in the recordings are: 1
#
#
# Data from: Training DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Desk work' 'Sitting' 'Movement' 'Running' 'Standing'
#  'Sitting bent backward' 'Descending stairs' 'Lying down right'
#  'Lying down on stomach' 'Lying down on back' 'Sitting bent forward'
#  'Climbing stairs' 'Walking at normal speed' 'Lying down left']
# The number of activities collected: 14
# The number of unique recordings is: 1077
# The subject IDs in the recordings are: 78
#
#
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_88 (Conv1D)          (None, 48, 64)            1216
#
#  batch_normalization_88 (Bat  (None, 48, 64)           256
#  chNormalization)
#
#  activation_88 (Activation)  (None, 48, 64)            0
#
#  conv1d_89 (Conv1D)          (None, 46, 64)            12352
#
#  batch_normalization_89 (Bat  (None, 46, 64)           256
#  chNormalization)
#
#  activation_89 (Activation)  (None, 46, 64)            0
#
#  conv1d_90 (Conv1D)          (None, 44, 64)            12352
#
#  batch_normalization_90 (Bat  (None, 44, 64)           256
#  chNormalization)
#
#  activation_90 (Activation)  (None, 44, 64)            0
#
#  conv1d_91 (Conv1D)          (None, 42, 64)            12352
#
#  batch_normalization_91 (Bat  (None, 42, 64)           256
#  chNormalization)
#
#  activation_91 (Activation)  (None, 42, 64)            0
#
#  flatten_22 (Flatten)        (None, 2688)              0
#
#  dense_44 (Dense)            (None, 100)               268900
#
#  dense_45 (Dense)            (None, 4)                 404
#
# =================================================================
# Total params: 308,600
# Trainable params: 308,088
# Non-trainable params: 512
# _________________________________________________________________
# Epoch 1/7
# 771/771 [==============================] - 7s 8ms/step - loss: 0.1503 - accuracy: 0.9511
# Epoch 2/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0735 - accuracy: 0.9746
# Epoch 3/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0589 - accuracy: 0.9798
# Epoch 4/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0524 - accuracy: 0.9828
# Epoch 5/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0512 - accuracy: 0.9836
# Epoch 6/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0412 - accuracy: 0.9856
# Epoch 7/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0360 - accuracy: 0.9873
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 1.0000
# 23 Iteration completed.
# Accuracy of 100.0 achieved.
# Data from: Testing DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Sitting bent backward' 'Standing' 'Lying down on back'
#  'Lying down right' 'Movement' 'Descending stairs'
#  'Walking at normal speed' 'Lying down left' 'Sitting' 'Running'
#  'Desk work' 'Sitting bent forward' 'Lying down on stomach'
#  'Climbing stairs']
# The number of activities collected: 14
# The number of unique recordings is: 14
# The subject IDs in the recordings are: 1
#
#
# Data from: Training DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Desk work' 'Sitting' 'Movement' 'Running' 'Standing'
#  'Sitting bent backward' 'Descending stairs' 'Lying down right'
#  'Lying down on stomach' 'Lying down on back' 'Sitting bent forward'
#  'Climbing stairs' 'Walking at normal speed' 'Lying down left']
# The number of activities collected: 14
# The number of unique recordings is: 1077
# The subject IDs in the recordings are: 78
#
#
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_92 (Conv1D)          (None, 48, 64)            1216
#
#  batch_normalization_92 (Bat  (None, 48, 64)           256
#  chNormalization)
#
#  activation_92 (Activation)  (None, 48, 64)            0
#
#  conv1d_93 (Conv1D)          (None, 46, 64)            12352
#
#  batch_normalization_93 (Bat  (None, 46, 64)           256
#  chNormalization)
#
#  activation_93 (Activation)  (None, 46, 64)            0
#
#  conv1d_94 (Conv1D)          (None, 44, 64)            12352
#
#  batch_normalization_94 (Bat  (None, 44, 64)           256
#  chNormalization)
#
#  activation_94 (Activation)  (None, 44, 64)            0
#
#  conv1d_95 (Conv1D)          (None, 42, 64)            12352
#
#  batch_normalization_95 (Bat  (None, 42, 64)           256
#  chNormalization)
#
#  activation_95 (Activation)  (None, 42, 64)            0
#
#  flatten_23 (Flatten)        (None, 2688)              0
#
#  dense_46 (Dense)            (None, 100)               268900
#
#  dense_47 (Dense)            (None, 4)                 404
#
# =================================================================
# Total params: 308,600
# Trainable params: 308,088
# Non-trainable params: 512
# _________________________________________________________________
# Epoch 1/7
# 771/771 [==============================] - 7s 8ms/step - loss: 0.1578 - accuracy: 0.9474
# Epoch 2/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0714 - accuracy: 0.9760
# Epoch 3/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0667 - accuracy: 0.9783
# Epoch 4/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0558 - accuracy: 0.9813
# Epoch 5/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0530 - accuracy: 0.9829
# Epoch 6/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0438 - accuracy: 0.9856
# Epoch 7/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0413 - accuracy: 0.9851
# 10/10 [==============================] - 0s 5ms/step - loss: 7.8963e-04 - accuracy: 1.0000
# 24 Iteration completed.
# Accuracy of 100.0 achieved.
# Data from: Testing DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Running' 'Movement' 'Sitting bent backward' 'Lying down on stomach'
#  'Lying down right' 'Desk work' 'Descending stairs' 'Standing'
#  'Lying down left' 'Walking at normal speed' 'Sitting bent forward'
#  'Lying down on back' 'Climbing stairs' 'Sitting']
# The number of activities collected: 14
# The number of unique recordings is: 14
# The subject IDs in the recordings are: 1
#
#
# Data from: Training DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Desk work' 'Sitting' 'Movement' 'Running' 'Standing'
#  'Sitting bent backward' 'Descending stairs' 'Lying down right'
#  'Lying down on stomach' 'Lying down on back' 'Sitting bent forward'
#  'Climbing stairs' 'Walking at normal speed' 'Lying down left']
# The number of activities collected: 14
# The number of unique recordings is: 1077
# The subject IDs in the recordings are: 78
#
#
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_96 (Conv1D)          (None, 48, 64)            1216
#
#  batch_normalization_96 (Bat  (None, 48, 64)           256
#  chNormalization)
#
#  activation_96 (Activation)  (None, 48, 64)            0
#
#  conv1d_97 (Conv1D)          (None, 46, 64)            12352
#
#  batch_normalization_97 (Bat  (None, 46, 64)           256
#  chNormalization)
#
#  activation_97 (Activation)  (None, 46, 64)            0
#
#  conv1d_98 (Conv1D)          (None, 44, 64)            12352
#
#  batch_normalization_98 (Bat  (None, 44, 64)           256
#  chNormalization)
#
#  activation_98 (Activation)  (None, 44, 64)            0
#
#  conv1d_99 (Conv1D)          (None, 42, 64)            12352
#
#  batch_normalization_99 (Bat  (None, 42, 64)           256
#  chNormalization)
#
#  activation_99 (Activation)  (None, 42, 64)            0
#
#  flatten_24 (Flatten)        (None, 2688)              0
#
#  dense_48 (Dense)            (None, 100)               268900
#
#  dense_49 (Dense)            (None, 4)                 404
#
# =================================================================
# Total params: 308,600
# Trainable params: 308,088
# Non-trainable params: 512
# _________________________________________________________________
# Epoch 1/7
# 771/771 [==============================] - 7s 8ms/step - loss: 0.1591 - accuracy: 0.9475
# Epoch 2/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0750 - accuracy: 0.9749
# Epoch 3/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0619 - accuracy: 0.9773
# Epoch 4/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0516 - accuracy: 0.9824
# Epoch 5/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0476 - accuracy: 0.9843
# Epoch 6/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0441 - accuracy: 0.9843
# Epoch 7/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0375 - accuracy: 0.9875
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0230 - accuracy: 0.9906
# 25 Iteration completed.
# Accuracy of 99.05956387519836 achieved.
# Data from: Testing DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Standing' 'Climbing stairs' 'Desk work' 'Sitting bent backward'
#  'Sitting bent forward' 'Running' 'Lying down left' 'Movement'
#  'Lying down on stomach' 'Walking at normal speed' 'Lying down on back'
#  'Sitting' 'Descending stairs' 'Lying down right']
# The number of activities collected: 14
# The number of unique recordings is: 14
# The subject IDs in the recordings are: 1
#
#
# Data from: Training DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Desk work' 'Sitting' 'Movement' 'Running' 'Standing'
#  'Sitting bent backward' 'Descending stairs' 'Lying down right'
#  'Lying down on stomach' 'Lying down on back' 'Sitting bent forward'
#  'Climbing stairs' 'Walking at normal speed' 'Lying down left']
# The number of activities collected: 14
# The number of unique recordings is: 1077
# The subject IDs in the recordings are: 78
#
#
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_100 (Conv1D)         (None, 48, 64)            1216
#
#  batch_normalization_100 (Ba  (None, 48, 64)           256
#  tchNormalization)
#
#  activation_100 (Activation)  (None, 48, 64)           0
#
#  conv1d_101 (Conv1D)         (None, 46, 64)            12352
#
#  batch_normalization_101 (Ba  (None, 46, 64)           256
#  tchNormalization)
#
#  activation_101 (Activation)  (None, 46, 64)           0
#
#  conv1d_102 (Conv1D)         (None, 44, 64)            12352
#
#  batch_normalization_102 (Ba  (None, 44, 64)           256
#  tchNormalization)
#
#  activation_102 (Activation)  (None, 44, 64)           0
#
#  conv1d_103 (Conv1D)         (None, 42, 64)            12352
#
#  batch_normalization_103 (Ba  (None, 42, 64)           256
#  tchNormalization)
#
#  activation_103 (Activation)  (None, 42, 64)           0
#
#  flatten_25 (Flatten)        (None, 2688)              0
#
#  dense_50 (Dense)            (None, 100)               268900
#
#  dense_51 (Dense)            (None, 4)                 404
#
# =================================================================
# Total params: 308,600
# Trainable params: 308,088
# Non-trainable params: 512
# _________________________________________________________________
# Epoch 1/7
# 771/771 [==============================] - 8s 8ms/step - loss: 0.1549 - accuracy: 0.9497
# Epoch 2/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0822 - accuracy: 0.9734
# Epoch 3/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0673 - accuracy: 0.9772
# Epoch 4/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0560 - accuracy: 0.9805
# Epoch 5/7
# 771/771 [==============================] - 7s 8ms/step - loss: 0.0481 - accuracy: 0.9835
# Epoch 6/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0456 - accuracy: 0.9832
# Epoch 7/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0431 - accuracy: 0.9850
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0405 - accuracy: 0.9937
# 26 Iteration completed.
# Accuracy of 99.37304258346558 achieved.
# Data from: Testing DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Lying down on stomach' 'Movement' 'Walking at normal speed'
#  'Lying down right' 'Sitting bent backward' 'Sitting bent forward'
#  'Standing' 'Climbing stairs' 'Lying down left' 'Desk work'
#  'Lying down on back' 'Running' 'Sitting' 'Descending stairs']
# The number of activities collected: 14
# The number of unique recordings is: 14
# The subject IDs in the recordings are: 1
#
#
# Data from: Training DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Desk work' 'Sitting' 'Movement' 'Running' 'Standing'
#  'Sitting bent backward' 'Descending stairs' 'Lying down right'
#  'Lying down on stomach' 'Lying down on back' 'Sitting bent forward'
#  'Climbing stairs' 'Walking at normal speed' 'Lying down left']
# The number of activities collected: 14
# The number of unique recordings is: 1077
# The subject IDs in the recordings are: 78
#
#
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_104 (Conv1D)         (None, 48, 64)            1216
#
#  batch_normalization_104 (Ba  (None, 48, 64)           256
#  tchNormalization)
#
#  activation_104 (Activation)  (None, 48, 64)           0
#
#  conv1d_105 (Conv1D)         (None, 46, 64)            12352
#
#  batch_normalization_105 (Ba  (None, 46, 64)           256
#  tchNormalization)
#
#  activation_105 (Activation)  (None, 46, 64)           0
#
#  conv1d_106 (Conv1D)         (None, 44, 64)            12352
#
#  batch_normalization_106 (Ba  (None, 44, 64)           256
#  tchNormalization)
#
#  activation_106 (Activation)  (None, 44, 64)           0
#
#  conv1d_107 (Conv1D)         (None, 42, 64)            12352
#
#  batch_normalization_107 (Ba  (None, 42, 64)           256
#  tchNormalization)
#
#  activation_107 (Activation)  (None, 42, 64)           0
#
#  flatten_26 (Flatten)        (None, 2688)              0
#
#  dense_52 (Dense)            (None, 100)               268900
#
#  dense_53 (Dense)            (None, 4)                 404
#
# =================================================================
# Total params: 308,600
# Trainable params: 308,088
# Non-trainable params: 512
# _________________________________________________________________
# Epoch 1/7
# 771/771 [==============================] - 7s 8ms/step - loss: 0.1587 - accuracy: 0.9470
# Epoch 2/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0697 - accuracy: 0.9753
# Epoch 3/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0667 - accuracy: 0.9771
# Epoch 4/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0517 - accuracy: 0.9821
# Epoch 5/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0497 - accuracy: 0.9835
# Epoch 6/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0550 - accuracy: 0.9818
# Epoch 7/7
# 771/771 [==============================] - 6s 8ms/step - loss: 0.0507 - accuracy: 0.9828
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0202 - accuracy: 1.0000
# 27 Iteration completed.
# Accuracy of 100.0 achieved.
# Data from: Testing DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Movement' 'Descending stairs' 'Standing' 'Walking at normal speed'
#  'Running' 'Lying down right' 'Sitting' 'Lying down on back'
#  'Climbing stairs' 'Desk work' 'Lying down left' 'Sitting bent forward'
#  'Lying down on stomach' 'Sitting bent backward']
# The number of activities collected: 14
# The number of unique recordings is: 14
# The subject IDs in the recordings are: 2
#
#
# Data from: Training DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Desk work' 'Sitting' 'Movement' 'Running' 'Standing'
#  'Sitting bent backward' 'Descending stairs' 'Lying down right'
#  'Lying down on stomach' 'Lying down on back' 'Sitting bent forward'
#  'Climbing stairs' 'Walking at normal speed' 'Lying down left']
# The number of activities collected: 14
# The number of unique recordings is: 1077
# The subject IDs in the recordings are: 77
#
#
# Model: "sequential_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_108 (Conv1D)         (None, 48, 64)            1216
#
#  batch_normalization_108 (Ba  (None, 48, 64)           256
#  tchNormalization)
#
#  activation_108 (Activation)  (None, 48, 64)           0
#
#  conv1d_109 (Conv1D)         (None, 46, 64)            12352
#
#  batch_normalization_109 (Ba  (None, 46, 64)           256
# ...
#  activation_297 (Activation)  (None, 46, 64)           0
#
#  conv1d_298 (Conv1D)         (None, 44, 64)            12352
#
#  batch_normalization_298 (Ba  (None, 44, 64)           256
#  tchNormalization)
#
#  activation_298 (Activation)  (None, 44, 64)           0
#
#  conv1d_299 (Conv1D)         (None, 42, 64)            12352
#
#  batch_normalization_299 (Ba  (None, 42, 64)           256
#  tchNormalization)
#
#  activation_299 (Activation)  (None, 42, 64)           0
#
#  flatten_74 (Flatten)        (None, 2688)              0
#
#  dense_148 (Dense)           (None, 100)               268900
#
#  dense_149 (Dense)           (None, 4)                 404
#
# =================================================================
# Total params: 308,600
# Trainable params: 308,088
# Non-trainable params: 512
# _________________________________________________________________
# Epoch 1/7
# 770/770 [==============================] - 9s 9ms/step - loss: 0.1514 - accuracy: 0.9515
# Epoch 2/7
# 770/770 [==============================] - 7s 9ms/step - loss: 0.0789 - accuracy: 0.9731
# Epoch 3/7
# 770/770 [==============================] - 7s 9ms/step - loss: 0.0638 - accuracy: 0.9776
# Epoch 4/7
# 770/770 [==============================] - 7s 9ms/step - loss: 0.0556 - accuracy: 0.9795
# Epoch 5/7
# 770/770 [==============================] - 7s 9ms/step - loss: 0.0456 - accuracy: 0.9846
# Epoch 6/7
# 770/770 [==============================] - 7s 9ms/step - loss: 0.0430 - accuracy: 0.9845
# Epoch 7/7
# 770/770 [==============================] - 7s 9ms/step - loss: 0.0420 - accuracy: 0.9849
# 11/11 [==============================] - 0s 4ms/step - loss: 0.4124 - accuracy: 0.9061
# 75 Iteration completed.
# Accuracy of 90.60605764389038 achieved.
# Data from: Testing DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Climbing stairs' 'Movement' 'Sitting bent forward' 'Standing'
#  'Walking at normal speed' 'Lying down on back' 'Running' 'Desk work'
#  'Lying down left' 'Sitting bent backward' 'Lying down on stomach'
#  'Sitting' 'Lying down right' 'Descending stairs']
# The number of activities collected: 14
# The number of unique recordings is: 14
# The subject IDs in the recordings are: 1
#
#
# Data from: Training DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Desk work' 'Sitting' 'Movement' 'Running' 'Standing'
#  'Sitting bent backward' 'Descending stairs' 'Lying down right'
#  'Lying down on stomach' 'Lying down on back' 'Sitting bent forward'
#  'Climbing stairs' 'Walking at normal speed' 'Lying down left']
# The number of activities collected: 14
# The number of unique recordings is: 1077
# The subject IDs in the recordings are: 78
#
#
# Model: "sequential_75"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_300 (Conv1D)         (None, 48, 64)            1216
#
#  batch_normalization_300 (Ba  (None, 48, 64)           256
#  tchNormalization)
#
#  activation_300 (Activation)  (None, 48, 64)           0
#
#  conv1d_301 (Conv1D)         (None, 46, 64)            12352
#
#  batch_normalization_301 (Ba  (None, 46, 64)           256
#  tchNormalization)
#
#  activation_301 (Activation)  (None, 46, 64)           0
#
#  conv1d_302 (Conv1D)         (None, 44, 64)            12352
#
#  batch_normalization_302 (Ba  (None, 44, 64)           256
#  tchNormalization)
#
#  activation_302 (Activation)  (None, 44, 64)           0
#
#  conv1d_303 (Conv1D)         (None, 42, 64)            12352
#
#  batch_normalization_303 (Ba  (None, 42, 64)           256
#  tchNormalization)
#
#  activation_303 (Activation)  (None, 42, 64)           0
#
#  flatten_75 (Flatten)        (None, 2688)              0
#
#  dense_150 (Dense)           (None, 100)               268900
#
#  dense_151 (Dense)           (None, 4)                 404
#
# =================================================================
# Total params: 308,600
# Trainable params: 308,088
# Non-trainable params: 512
# _________________________________________________________________
# Epoch 1/7
# 771/771 [==============================] - 8s 9ms/step - loss: 0.1597 - accuracy: 0.9464
# Epoch 2/7
# 771/771 [==============================] - 7s 9ms/step - loss: 0.0730 - accuracy: 0.9739
# Epoch 3/7
# 771/771 [==============================] - 7s 9ms/step - loss: 0.0603 - accuracy: 0.9791
# Epoch 4/7
# 771/771 [==============================] - 7s 9ms/step - loss: 0.0538 - accuracy: 0.9807
# Epoch 5/7
# 771/771 [==============================] - 7s 9ms/step - loss: 0.0456 - accuracy: 0.9842
# Epoch 6/7
# 771/771 [==============================] - 7s 9ms/step - loss: 0.0453 - accuracy: 0.9842
# Epoch 7/7
# 771/771 [==============================] - 7s 9ms/step - loss: 0.0427 - accuracy: 0.9854
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 1.0000
# 76 Iteration completed.
# Accuracy of 100.0 achieved.
# Data from: Testing DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Lying down on stomach' 'Lying down right' 'Walking at normal speed'
#  'Desk work' 'Sitting bent backward' 'Sitting bent forward'
#  'Lying down on back' 'Standing' 'Climbing stairs' 'Movement'
#  'Descending stairs' 'Lying down left' 'Running' 'Sitting']
# The number of activities collected: 14
# The number of unique recordings is: 14
# The subject IDs in the recordings are: 1
#
#
# Data from: Training DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Desk work' 'Sitting' 'Movement' 'Running' 'Standing'
#  'Sitting bent backward' 'Descending stairs' 'Lying down right'
#  'Lying down on stomach' 'Lying down on back' 'Sitting bent forward'
#  'Climbing stairs' 'Walking at normal speed' 'Lying down left']
# The number of activities collected: 14
# The number of unique recordings is: 1077
# The subject IDs in the recordings are: 78
#
#
# Model: "sequential_76"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_304 (Conv1D)         (None, 48, 64)            1216
#
#  batch_normalization_304 (Ba  (None, 48, 64)           256
#  tchNormalization)
#
#  activation_304 (Activation)  (None, 48, 64)           0
#
#  conv1d_305 (Conv1D)         (None, 46, 64)            12352
#
#  batch_normalization_305 (Ba  (None, 46, 64)           256
#  tchNormalization)
#
#  activation_305 (Activation)  (None, 46, 64)           0
#
#  conv1d_306 (Conv1D)         (None, 44, 64)            12352
#
#  batch_normalization_306 (Ba  (None, 44, 64)           256
#  tchNormalization)
#
#  activation_306 (Activation)  (None, 44, 64)           0
#
#  conv1d_307 (Conv1D)         (None, 42, 64)            12352
#
#  batch_normalization_307 (Ba  (None, 42, 64)           256
#  tchNormalization)
#
#  activation_307 (Activation)  (None, 42, 64)           0
#
#  flatten_76 (Flatten)        (None, 2688)              0
#
#  dense_152 (Dense)           (None, 100)               268900
#
#  dense_153 (Dense)           (None, 4)                 404
#
# =================================================================
# Total params: 308,600
# Trainable params: 308,088
# Non-trainable params: 512
# _________________________________________________________________
# Epoch 1/7
# 770/770 [==============================] - 8s 9ms/step - loss: 0.1492 - accuracy: 0.9515
# Epoch 2/7
# 770/770 [==============================] - 7s 9ms/step - loss: 0.0735 - accuracy: 0.9751
# Epoch 3/7
# 770/770 [==============================] - 7s 9ms/step - loss: 0.0568 - accuracy: 0.9799
# Epoch 4/7
# 770/770 [==============================] - 7s 9ms/step - loss: 0.0488 - accuracy: 0.9820
# Epoch 5/7
# 770/770 [==============================] - 7s 9ms/step - loss: 0.0450 - accuracy: 0.9837
# Epoch 6/7
# 770/770 [==============================] - 7s 9ms/step - loss: 0.0368 - accuracy: 0.9873
# Epoch 7/7
# 770/770 [==============================] - 7s 9ms/step - loss: 0.0377 - accuracy: 0.9866
# 11/11 [==============================] - 0s 5ms/step - loss: 1.0143 - accuracy: 0.8994
# 77 Iteration completed.
# Accuracy of 89.93902206420898 achieved.
# Data from: Testing DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Descending stairs' 'Sitting bent forward' 'Movement'
#  'Sitting bent backward' 'Climbing stairs' 'Lying down right'
#  'Lying down on stomach' 'Lying down left' 'Lying down on back'
#  'Desk work' 'Running' 'Sitting' 'Walking at normal speed' 'Standing']
# The number of activities collected: 14
# The number of unique recordings is: 14
# The subject IDs in the recordings are: 1
#
#
# Data from: Training DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Desk work' 'Sitting' 'Movement' 'Running' 'Standing'
#  'Sitting bent backward' 'Descending stairs' 'Lying down right'
#  'Lying down on stomach' 'Lying down on back' 'Sitting bent forward'
#  'Climbing stairs' 'Walking at normal speed' 'Lying down left']
# The number of activities collected: 14
# The number of unique recordings is: 1077
# The subject IDs in the recordings are: 78
#
#
# Model: "sequential_77"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_308 (Conv1D)         (None, 48, 64)            1216
#
#  batch_normalization_308 (Ba  (None, 48, 64)           256
#  tchNormalization)
#
#  activation_308 (Activation)  (None, 48, 64)           0
#
#  conv1d_309 (Conv1D)         (None, 46, 64)            12352
#
#  batch_normalization_309 (Ba  (None, 46, 64)           256
#  tchNormalization)
#
#  activation_309 (Activation)  (None, 46, 64)           0
#
#  conv1d_310 (Conv1D)         (None, 44, 64)            12352
#
#  batch_normalization_310 (Ba  (None, 44, 64)           256
#  tchNormalization)
#
#  activation_310 (Activation)  (None, 44, 64)           0
#
#  conv1d_311 (Conv1D)         (None, 42, 64)            12352
#
#  batch_normalization_311 (Ba  (None, 42, 64)           256
#  tchNormalization)
#
#  activation_311 (Activation)  (None, 42, 64)           0
#
#  flatten_77 (Flatten)        (None, 2688)              0
#
#  dense_154 (Dense)           (None, 100)               268900
#
#  dense_155 (Dense)           (None, 4)                 404
#
# =================================================================
# Total params: 308,600
# Trainable params: 308,088
# Non-trainable params: 512
# _________________________________________________________________
# Epoch 1/7
# 771/771 [==============================] - 8s 9ms/step - loss: 0.1635 - accuracy: 0.9458
# Epoch 2/7
# 771/771 [==============================] - 7s 9ms/step - loss: 0.0783 - accuracy: 0.9735
# Epoch 3/7
# 771/771 [==============================] - 7s 9ms/step - loss: 0.0619 - accuracy: 0.9787
# Epoch 4/7
# 771/771 [==============================] - 7s 9ms/step - loss: 0.0531 - accuracy: 0.9819
# Epoch 5/7
# 771/771 [==============================] - 7s 9ms/step - loss: 0.0576 - accuracy: 0.9797
# Epoch 6/7
# 771/771 [==============================] - 7s 9ms/step - loss: 0.0428 - accuracy: 0.9848
# Epoch 7/7
# 771/771 [==============================] - 7s 9ms/step - loss: 0.0395 - accuracy: 0.9859
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1648 - accuracy: 0.9500
# 78 Iteration completed.
# Accuracy of 94.9999988079071 achieved.

# %%
mean_score = sum(accuracies) / len(accuracies)
print("Mean Score of Model: ", mean_score)
# Out:
# Mean Score of Model:  97.08224481497055
