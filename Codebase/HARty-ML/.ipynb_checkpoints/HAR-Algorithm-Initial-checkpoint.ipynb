# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import random
import tensorflow as tf
from sklearn.metrics import classification_report
from sklearn import metrics
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Embedding, Conv1D, Dropout, MaxPooling1D, BatchNormalization, TimeDistributed, LSTM
from tensorflow.keras import optimizers

# %% [markdown]
# Run subject_segregation.py and check-subject-validity.py prior to this.

# %%
#Create uun list for testing, training and validation

random.seed(100)
src_folder = '../processed-data/By-UUN/'

uun_list = [s for s in os.listdir(src_folder) if s[0]== 's']
uun_list = random.sample(uun_list,len(uun_list))

training_list = uun_list[0:63] 
testing_list = uun_list[63:71]
validation_list = uun_list[71:]

print("Total size of list: " + str(len(uun_list)))
print("Total size of training list: " + str(len(training_list)))
print("Total size of testing list: " + str(len(testing_list)))
print("Total size of validation list: " + str(len(validation_list)))
if (len(uun_list) == (len(training_list) + len(testing_list) + len(validation_list))):
    print("List indexed correctly.")
else:
    print("List indexed incorrectly. Please check the input source again.")
# Out:
# Total size of list: 78
# Total size of training list: 63
# Total size of testing list: 8
# Total size of validation list: 7
# List indexed correctly.

# %%
def create_dataFrame(uun_list, df_name, src_folder):
    base_df = pd.DataFrame()
    
    for uun in uun_list:
        files_per_uun = [s for s in os.listdir(os.path.join(src_folder,uun))]
        
        for file in files_per_uun:
            # load data into a DataFrame 
            path = os.path.join(src_folder, uun, file)
            new_df = pd.read_csv(path)
            # merge into the base DataFrame 
            base_df = pd.concat([base_df, new_df])
            
    base_df.reset_index(drop=True, inplace=True)
    base_df.drop(base_df[base_df['sensor_type'] == "Thingy"].index, inplace = True)
    
    print(f"Data from: {df_name}")
    print(f"The data was collected using the sensors: {base_df.sensor_type.unique()}")
    print(f"The data was collected for the activities: {base_df.activity_type.unique()}")
    print(f"The number of activities collected: {len(base_df.activity_type.unique())}")
    print(f"The number of unique recordings is: {len(base_df.recording_id.unique())}")
    print(f"The subject IDs in the recordings are: {len(base_df.subject_id.unique())}")
    print("\n")
            
    return base_df

def clean_dataFrame(df):
    df.drop('notes', axis=1, inplace=True)
    df.drop('sensor_type', axis=1, inplace=True)
    df.drop('subject_id', axis=1, inplace=True)
    df.dropna(inplace=True)
    
def get_sliding_windows(df):
    recording_id_list = df.recording_id.unique()
    sliding_windows = pd.DataFrame()
    window_size = 50 # 50 datapoints for the window size, which, at 25Hz, means 2 seconds
    step_size = 25 # this is 50% overlap

    window_number = 0 # start a counter at 0 to keep track of the window number

    for recording in recording_id_list:
        current_window = df.loc[df['recording_id'] == recording]
        large_enough_windows = [window for window in current_window.rolling(window=window_size, min_periods=window_size) if len(window) == window_size]
        overlapping_windows = large_enough_windows[::step_size] 

        for window in overlapping_windows:
            window.loc[:, 'window_id'] = window_number
            window_number += 1

        final_sliding_windows = pd.concat(overlapping_windows)
        sliding_windows = pd.concat([sliding_windows, final_sliding_windows])

    sliding_windows.reset_index(drop=True, inplace=True)
    return sliding_windows

def model_data(df_sliding_windows):
    X = []
    y = []

    for window_id, group in df_sliding_windows.groupby('window_id'):
        print(f"window_id = {window_id}")

        shape = group[columns_of_interest].values.shape
        print(f"shape = {shape}")
        
        X.append(group[columns_of_interest].values)
        y.append(class_labels[group["activity_type"].values[0]])
        
    X = np.asarray(X)
    y = np.asarray(pd.get_dummies(np.asarray(y)), dtype=np.float32)
    return (X,y)

# %%
training_df = create_dataFrame(training_list, "Training DF", src_folder)
testing_df = create_dataFrame(testing_list, "Testing DF", src_folder)
validation_df = create_dataFrame(validation_list, "Validation DF", src_folder)
# Out:
# Data from: Training DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Walking at normal speed' 'Descending stairs' 'Lying down on back'
#  'Sitting bent backward' 'Lying down right' 'Movement'
#  'Sitting bent forward' 'Climbing stairs' 'Standing' 'Desk work' 'Sitting'
#  'Lying down left' 'Lying down on stomach' 'Running']
# The number of activities collected: 14
# The number of unique recordings is: 882
# The subject IDs in the recordings are: 64
#
#
# Data from: Testing DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Climbing stairs' 'Sitting bent backward' 'Lying down left'
#  'Walking at normal speed' 'Lying down on back' 'Movement'
#  'Lying down on stomach' 'Running' 'Lying down right'
#  'Sitting bent forward' 'Desk work' 'Sitting' 'Descending stairs'
#  'Standing']
# The number of activities collected: 14
# The number of unique recordings is: 112
# The subject IDs in the recordings are: 8
#
#
# Data from: Validation DF
# The data was collected using the sensors: ['Respeck']
# The data was collected for the activities: ['Sitting' 'Lying down left' 'Lying down on back' 'Standing'
#  'Sitting bent forward' 'Walking at normal speed' 'Lying down on stomach'
#  'Lying down right' 'Movement' 'Sitting bent backward' 'Desk work'
#  'Running' 'Climbing stairs' 'Descending stairs']
# The number of activities collected: 14
# The number of unique recordings is: 97
# The subject IDs in the recordings are: 7

# %%
clean_dataFrame(training_df)
clean_dataFrame(testing_df)
clean_dataFrame(validation_df)

# %%
training_df = training_df.apply(lambda x: (x - (-2.5))/(2.5 - (-2.5)) if x.name in ['accel_x', 'accel_y','accel_z'] else x)
training_df = training_df.apply(lambda x: (x - (-525.0))/(525.0 - (-525.0)) if x.name in ['gyro_x', 'gyro_y','gyro_z'] else x)

testing_df = testing_df.apply(lambda x: (x - (-2.5))/(2.5 - (-2.5)) if x.name in ['accel_x', 'accel_y','accel_z'] else x)
testing_df = testing_df.apply(lambda x: (x - (-525.0))/(525.0 - (-525.0)) if x.name in ['gyro_x', 'gyro_y','gyro_z'] else x)

validation_df = validation_df.apply(lambda x: (x - (-2.5))/(2.5 - (-2.5)) if x.name in ['accel_x', 'accel_y','accel_z'] else x)
validation_df = validation_df.apply(lambda x: (x - (-525.0))/(525.0 - (-525.0)) if x.name in ['gyro_x', 'gyro_y','gyro_z'] else x)

# %%
training_df
# Out:
#            timestamp   accel_x   accel_y   accel_z    gyro_x    gyro_y  \
# 0       1.664374e+12  0.346289  0.237634  0.463123  0.490074  0.496295
# 1       1.664374e+12  0.556348  0.281970  0.432605  0.519435  0.502217
# 2       1.664374e+12  0.471338  0.365173  0.446375  0.506220  0.521339
# 3       1.664374e+12  0.415234  0.311365  0.437830  0.488795  0.515253
# 4       1.664374e+12  0.484277  0.193640  0.482117  0.497515  0.494940
# ...              ...       ...       ...       ...       ...       ...
# 671973  1.663933e+12  0.505078  0.100000  0.429333  0.511146  0.567604
# 671974  1.663933e+12  0.572119  0.274597  0.527429  0.504539  0.555327
# 671975  1.663933e+12  0.453711  0.305408  0.482556  0.483452  0.517560
# 671976  1.663933e+12  0.456348  0.385486  0.468738  0.495640  0.537976
# 671977  1.663933e+12  0.561816  0.531628  0.429382  0.499613  0.525312
#
#           gyro_z            activity_type  activity_code  \
# 0       0.483527  Walking at normal speed              1
# 1       0.503333  Walking at normal speed              1
# 2       0.512262  Walking at normal speed              1
# 3       0.482976  Walking at normal speed              1
# 4       0.495342  Walking at normal speed              1
# ...          ...                      ...            ...
# 671973  0.491548                  Running             11
# 671974  0.502679                  Running             11
# 671975  0.483289                  Running             11
# 671976  0.508839                  Running             11
# 671977  0.521741                  Running             11
#
#                                              recording_id
# 0       Respeck_s1892493_Walking at normal speed_28-09...
# 1       Respeck_s1892493_Walking at normal speed_28-09...
# 2       Respeck_s1892493_Walking at normal speed_28-09...
# 3       Respeck_s1892493_Walking at normal speed_28-09...
# 4       Respeck_s1892493_Walking at normal speed_28-09...
# ...                                                   ...
# 671973       Respeck_s1908422_Running_23-09-2022_17-06-43
# 671974       Respeck_s1908422_Running_23-09-2022_17-06-43
# 671975       Respeck_s1908422_Running_23-09-2022_17-06-43
# 671976       Respeck_s1908422_Running_23-09-2022_17-06-43
# 671977       Respeck_s1908422_Running_23-09-2022_17-06-43
#
# [671977 rows x 10 columns]

# %%
training_sliding_windows = get_sliding_windows(training_df)
testing_sliding_windows = get_sliding_windows(testing_df)
validation_sliding_windows = get_sliding_windows(validation_df)

# %%
columns_of_interest = ['accel_x', 'accel_y', 'accel_z', 'gyro_x', 'gyro_y', 'gyro_z']

class_labels = {
    'Standing': 0,
    'Climbing stairs': 1,
    'Descending stairs': 2,
    'Desk work' : 3,
    'Lying down left' : 4,
    'Lying down on back' : 5,
    'Lying down on stomach' : 6,
    'Lying down right' : 7,
    'Running' : 8,
    'Sitting bent backward' : 9,
    'Sitting bent forward' : 10,
    'Sitting' : 11,
    'Walking at normal speed' : 12,
    'Movement' : 13
}

# %% [markdown]
# CNN Model Config

# %%
filters = 64
kernel_size = 3
n_features = 6
activation='relu'
n_classes = 14
window_size = 50

model = Sequential()

model.add(Conv1D(filters=filters, kernel_size=kernel_size, activation='linear', 
                 input_shape=(window_size, n_features)))
model.add(BatchNormalization())
model.add(Activation(activation))

model.add(Conv1D(filters=filters, kernel_size=kernel_size, activation='linear'))
model.add(BatchNormalization())
model.add(Activation(activation))

model.add(Conv1D(filters=filters, kernel_size=kernel_size, activation='linear'))
model.add(BatchNormalization())
model.add(Activation(activation))

model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(n_classes, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 48, 64)            1216
# _________________________________________________________________
# batch_normalization (BatchNo (None, 48, 64)            256
# _________________________________________________________________
# activation (Activation)      (None, 48, 64)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 46, 64)            12352
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 46, 64)            256
# _________________________________________________________________
# activation_1 (Activation)    (None, 46, 64)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 44, 64)            12352
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 44, 64)            256
# _________________________________________________________________
# activation_2 (Activation)    (None, 44, 64)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 2816)              0
# _________________________________________________________________
# dense (Dense)                (None, 100)               281700
# _________________________________________________________________
# dense_1 (Dense)              (None, 14)                1414
# =================================================================
# Total params: 309,802
# Trainable params: 309,418
# Non-trainable params: 384
# _________________________________________________________________
# 2022-11-07 23:31:39.348352: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-07 23:31:39.348779: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 10. Tune using inter_op_parallelism_threads for best performance.

# %%
(X_train, y_train) = model_data(training_sliding_windows)
(X_test, y_test) = model_data(testing_sliding_windows)
(X_validate, y_validate) = model_data(validation_sliding_windows)
# Out:
# window_id = 0
# shape = (50, 6)
# window_id = 1
# shape = (50, 6)
# window_id = 2
# shape = (50, 6)
# window_id = 3
# shape = (50, 6)
# window_id = 4
# shape = (50, 6)
# window_id = 5
# shape = (50, 6)
# window_id = 6
# shape = (50, 6)
# window_id = 7
# shape = (50, 6)
# window_id = 8
# shape = (50, 6)
# window_id = 9
# shape = (50, 6)
# window_id = 10
# shape = (50, 6)
# window_id = 11
# shape = (50, 6)
# window_id = 12
# shape = (50, 6)
# window_id = 13
# shape = (50, 6)
# window_id = 14
# shape = (50, 6)
# window_id = 15
# shape = (50, 6)
# window_id = 16
# shape = (50, 6)
# window_id = 17
# shape = (50, 6)
# window_id = 18
# shape = (50, 6)
# window_id = 19
# shape = (50, 6)
# window_id = 20
# shape = (50, 6)
# window_id = 21
# shape = (50, 6)
# window_id = 22
# shape = (50, 6)
# window_id = 23
# shape = (50, 6)
# window_id = 24
# shape = (50, 6)
# window_id = 25
# shape = (50, 6)
# window_id = 26
# shape = (50, 6)
# window_id = 27
# shape = (50, 6)
# window_id = 28
# shape = (50, 6)
# window_id = 29
# shape = (50, 6)
# window_id = 30
# shape = (50, 6)
# window_id = 31
# shape = (50, 6)
# window_id = 32
# shape = (50, 6)
# window_id = 33
# shape = (50, 6)
# window_id = 34
# shape = (50, 6)
# window_id = 35
# shape = (50, 6)
# window_id = 36
# shape = (50, 6)
# window_id = 37
# shape = (50, 6)
# window_id = 38
# shape = (50, 6)
# window_id = 39
# shape = (50, 6)
# window_id = 40
# shape = (50, 6)
# window_id = 41
# shape = (50, 6)
# window_id = 42
# shape = (50, 6)
# window_id = 43
# shape = (50, 6)
# window_id = 44
# shape = (50, 6)
# window_id = 45
# shape = (50, 6)
# window_id = 46
# shape = (50, 6)
# window_id = 47
# shape = (50, 6)
# window_id = 48
# shape = (50, 6)
# window_id = 49
# shape = (50, 6)
# window_id = 50
# shape = (50, 6)
# window_id = 51
# shape = (50, 6)
# window_id = 52
# shape = (50, 6)
# window_id = 53
# shape = (50, 6)
# window_id = 54
# shape = (50, 6)
# window_id = 55
# shape = (50, 6)
# window_id = 56
# shape = (50, 6)
# window_id = 57
# shape = (50, 6)
# window_id = 58
# shape = (50, 6)
# window_id = 59
# shape = (50, 6)
# window_id = 60
# shape = (50, 6)
# window_id = 61
# shape = (50, 6)
# window_id = 62
# shape = (50, 6)
# window_id = 63
# shape = (50, 6)
# window_id = 64
# shape = (50, 6)
# window_id = 65
# shape = (50, 6)
# window_id = 66
# shape = (50, 6)
# window_id = 67
# shape = (50, 6)
# window_id = 68
# shape = (50, 6)
# window_id = 69
# shape = (50, 6)
# window_id = 70
# shape = (50, 6)
# window_id = 71
# shape = (50, 6)
# window_id = 72
# shape = (50, 6)
# window_id = 73
# shape = (50, 6)
# window_id = 74
# shape = (50, 6)
# window_id = 75
# shape = (50, 6)
# window_id = 76
# shape = (50, 6)
# window_id = 77
# shape = (50, 6)
# window_id = 78
# shape = (50, 6)
# window_id = 79
# shape = (50, 6)
# window_id = 80
# shape = (50, 6)
# window_id = 81
# shape = (50, 6)
# window_id = 82
# shape = (50, 6)
# window_id = 83
# shape = (50, 6)
# window_id = 84
# shape = (50, 6)
# window_id = 85
# shape = (50, 6)
# window_id = 86
# shape = (50, 6)
# window_id = 87
# shape = (50, 6)
# window_id = 88
# shape = (50, 6)
# window_id = 89
# shape = (50, 6)
# window_id = 90
# shape = (50, 6)
# window_id = 91
# shape = (50, 6)
# window_id = 92
# shape = (50, 6)
# window_id = 93
# shape = (50, 6)
# window_id = 94
# shape = (50, 6)
# window_id = 95
# shape = (50, 6)
# window_id = 96
# shape = (50, 6)
# window_id = 97
# shape = (50, 6)
# window_id = 98
# shape = (50, 6)
# window_id = 99
# shape = (50, 6)
# window_id = 100
# shape = (50, 6)
# window_id = 101
# shape = (50, 6)
# window_id = 102
# shape = (50, 6)
# window_id = 103
# shape = (50, 6)
# window_id = 104
# shape = (50, 6)
# window_id = 105
# shape = (50, 6)
# window_id = 106
# shape = (50, 6)
# window_id = 107
# shape = (50, 6)
# window_id = 108
# shape = (50, 6)
# window_id = 109
# shape = (50, 6)
# window_id = 110
# shape = (50, 6)
# window_id = 111
# shape = (50, 6)
# window_id = 112
# shape = (50, 6)
# window_id = 113
# shape = (50, 6)
# window_id = 114
# shape = (50, 6)
# window_id = 115
# shape = (50, 6)
# window_id = 116
# shape = (50, 6)
# window_id = 117
# shape = (50, 6)
# window_id = 118
# shape = (50, 6)
# window_id = 119
# shape = (50, 6)
# window_id = 120
# shape = (50, 6)
# window_id = 121
# shape = (50, 6)
# window_id = 122
# shape = (50, 6)
# window_id = 123
# shape = (50, 6)
# window_id = 124
# shape = (50, 6)
# window_id = 125
# shape = (50, 6)
# window_id = 126
# shape = (50, 6)
# window_id = 127
# shape = (50, 6)
# window_id = 128
# shape = (50, 6)
# window_id = 129
# shape = (50, 6)
# window_id = 130
# shape = (50, 6)
# window_id = 131
# shape = (50, 6)
# window_id = 132
# shape = (50, 6)
# window_id = 133
# shape = (50, 6)
# window_id = 134
# shape = (50, 6)
# window_id = 135
# shape = (50, 6)
# window_id = 136
# shape = (50, 6)
# window_id = 137
# shape = (50, 6)
# window_id = 138
# shape = (50, 6)
# window_id = 139
# shape = (50, 6)
# window_id = 140
# shape = (50, 6)
# window_id = 141
# shape = (50, 6)
# window_id = 142
# shape = (50, 6)
# window_id = 143
# shape = (50, 6)
# window_id = 144
# shape = (50, 6)
# window_id = 145
# shape = (50, 6)
# window_id = 146
# shape = (50, 6)
# window_id = 147
# shape = (50, 6)
# window_id = 148
# shape = (50, 6)
# window_id = 149
# shape = (50, 6)
# window_id = 150
# shape = (50, 6)
# window_id = 151
# shape = (50, 6)
# window_id = 152
# shape = (50, 6)
# window_id = 153
# shape = (50, 6)
# window_id = 154
# shape = (50, 6)
# window_id = 155
# shape = (50, 6)
# window_id = 156
# shape = (50, 6)
# window_id = 157
# shape = (50, 6)
# window_id = 158
# shape = (50, 6)
# window_id = 159
# shape = (50, 6)
# window_id = 160
# shape = (50, 6)
# window_id = 161
# shape = (50, 6)
# window_id = 162
# shape = (50, 6)
# window_id = 163
# shape = (50, 6)
# window_id = 164
# shape = (50, 6)
# window_id = 165
# shape = (50, 6)
# window_id = 166
# shape = (50, 6)
# window_id = 167
# shape = (50, 6)
# window_id = 168
# shape = (50, 6)
# window_id = 169
# shape = (50, 6)
# window_id = 170
# shape = (50, 6)
# window_id = 171
# shape = (50, 6)
# window_id = 172
# shape = (50, 6)
# window_id = 173
# shape = (50, 6)
# window_id = 174
# shape = (50, 6)
# window_id = 175
# shape = (50, 6)
# window_id = 176
# shape = (50, 6)
# window_id = 177
# shape = (50, 6)
# window_id = 178
# shape = (50, 6)
# window_id = 179
# shape = (50, 6)
# window_id = 180
# shape = (50, 6)
# window_id = 181
# shape = (50, 6)
# window_id = 182
# shape = (50, 6)
# window_id = 183
# shape = (50, 6)
# window_id = 184
# shape = (50, 6)
# window_id = 185
# shape = (50, 6)
# window_id = 186
# shape = (50, 6)
# window_id = 187
# shape = (50, 6)
# window_id = 188
# shape = (50, 6)
# window_id = 189
# shape = (50, 6)
# window_id = 190
# shape = (50, 6)
# window_id = 191
# shape = (50, 6)
# window_id = 192
# shape = (50, 6)
# window_id = 193
# shape = (50, 6)
# window_id = 194
# shape = (50, 6)
# window_id = 195
# shape = (50, 6)
# window_id = 196
# shape = (50, 6)
# window_id = 197
# shape = (50, 6)
# window_id = 198
# shape = (50, 6)
# window_id = 199
# shape = (50, 6)
# window_id = 200
# shape = (50, 6)
# window_id = 201
# shape = (50, 6)
# window_id = 202
# shape = (50, 6)
# window_id = 203
# shape = (50, 6)
# window_id = 204
# shape = (50, 6)
# window_id = 205
# shape = (50, 6)
# window_id = 206
# shape = (50, 6)
# window_id = 207
# shape = (50, 6)
# window_id = 208
# shape = (50, 6)
# window_id = 209
# shape = (50, 6)
# window_id = 210
# shape = (50, 6)
# window_id = 211
# shape = (50, 6)
# window_id = 212
# shape = (50, 6)
# window_id = 213
# shape = (50, 6)
# window_id = 214
# shape = (50, 6)
# window_id = 215
# shape = (50, 6)
# window_id = 216
# shape = (50, 6)
# window_id = 217
# shape = (50, 6)
# window_id = 218
# shape = (50, 6)
# window_id = 219
# shape = (50, 6)
# window_id = 220
# shape = (50, 6)
# window_id = 221
# shape = (50, 6)
# window_id = 222
# shape = (50, 6)
# window_id = 223
# shape = (50, 6)
# window_id = 224
# shape = (50, 6)
# window_id = 225
# shape = (50, 6)
# window_id = 226
# shape = (50, 6)
# window_id = 227
# shape = (50, 6)
# window_id = 228
# shape = (50, 6)
# window_id = 229
# shape = (50, 6)
# window_id = 230
# shape = (50, 6)
# window_id = 231
# shape = (50, 6)
# window_id = 232
# shape = (50, 6)
# window_id = 233
# shape = (50, 6)
# window_id = 234
# shape = (50, 6)
# window_id = 235
# shape = (50, 6)
# window_id = 236
# shape = (50, 6)
# window_id = 237
# shape = (50, 6)
# window_id = 238
# shape = (50, 6)
# window_id = 239
# shape = (50, 6)
# window_id = 240
# shape = (50, 6)
# window_id = 241
# shape = (50, 6)
# window_id = 242
# shape = (50, 6)
# window_id = 243
# shape = (50, 6)
# window_id = 244
# shape = (50, 6)
# window_id = 245
# shape = (50, 6)
# window_id = 246
# shape = (50, 6)
# window_id = 247
# shape = (50, 6)
# window_id = 248
# shape = (50, 6)
# window_id = 249
# shape = (50, 6)
# window_id = 250
# shape = (50, 6)
# window_id = 251
# shape = (50, 6)
# window_id = 252
# shape = (50, 6)
# window_id = 253
# shape = (50, 6)
# window_id = 254
# shape = (50, 6)
# window_id = 255
# shape = (50, 6)
# window_id = 256
# shape = (50, 6)
# window_id = 257
# shape = (50, 6)
# window_id = 258
# shape = (50, 6)
# window_id = 259
# shape = (50, 6)
# window_id = 260
# shape = (50, 6)
# window_id = 261
# shape = (50, 6)
# window_id = 262
# shape = (50, 6)
# window_id = 263
# shape = (50, 6)
# window_id = 264
# shape = (50, 6)
# window_id = 265
# shape = (50, 6)
# window_id = 266
# shape = (50, 6)
# window_id = 267
# shape = (50, 6)
# window_id = 268
# shape = (50, 6)
# window_id = 269
# shape = (50, 6)
# window_id = 270
# shape = (50, 6)
# window_id = 271
# shape = (50, 6)
# window_id = 272
# shape = (50, 6)
# window_id = 273
# shape = (50, 6)
# window_id = 274
# shape = (50, 6)
# window_id = 275
# shape = (50, 6)
# window_id = 276
# shape = (50, 6)
# window_id = 277
# shape = (50, 6)
# window_id = 278
# shape = (50, 6)
# window_id = 279
# shape = (50, 6)
# window_id = 280
# shape = (50, 6)
# window_id = 281
# shape = (50, 6)
# window_id = 282
# shape = (50, 6)
# window_id = 283
# shape = (50, 6)
# window_id = 284
# shape = (50, 6)
# window_id = 285
# shape = (50, 6)
# window_id = 286
# shape = (50, 6)
# window_id = 287
# shape = (50, 6)
# window_id = 288
# shape = (50, 6)
# window_id = 289
# shape = (50, 6)
# window_id = 290
# shape = (50, 6)
# window_id = 291
# shape = (50, 6)
# window_id = 292
# shape = (50, 6)
# window_id = 293
# shape = (50, 6)
# window_id = 294
# shape = (50, 6)
# window_id = 295
# shape = (50, 6)
# window_id = 296
# shape = (50, 6)
# window_id = 297
# shape = (50, 6)
# window_id = 298
# shape = (50, 6)
# window_id = 299
# shape = (50, 6)
# window_id = 300
# shape = (50, 6)
# window_id = 301
# shape = (50, 6)
# window_id = 302
# shape = (50, 6)
# window_id = 303
# shape = (50, 6)
# window_id = 304
# shape = (50, 6)
# window_id = 305
# shape = (50, 6)
# window_id = 306
# shape = (50, 6)
# window_id = 307
# shape = (50, 6)
# window_id = 308
# shape = (50, 6)
# window_id = 309
# shape = (50, 6)
# window_id = 310
# shape = (50, 6)
# window_id = 311
# shape = (50, 6)
# window_id = 312
# shape = (50, 6)
# window_id = 313
# shape = (50, 6)
# window_id = 314
# shape = (50, 6)
# window_id = 315
# shape = (50, 6)
# window_id = 316
# shape = (50, 6)
# window_id = 317
# shape = (50, 6)
# window_id = 318
# shape = (50, 6)
# window_id = 319
# shape = (50, 6)
# window_id = 320
# shape = (50, 6)
# window_id = 321
# shape = (50, 6)
# window_id = 322
# shape = (50, 6)
# window_id = 323
# shape = (50, 6)
# window_id = 324
# shape = (50, 6)
# window_id = 325
# shape = (50, 6)
# window_id = 326
# shape = (50, 6)
# window_id = 327
# shape = (50, 6)
# window_id = 328
# shape = (50, 6)
# window_id = 329
# shape = (50, 6)
# window_id = 330
# shape = (50, 6)
# window_id = 331
# shape = (50, 6)
# window_id = 332
# shape = (50, 6)
# window_id = 333
# shape = (50, 6)
# window_id = 334
# shape = (50, 6)
# window_id = 335
# shape = (50, 6)
# window_id = 336
# shape = (50, 6)
# window_id = 337
# shape = (50, 6)
# window_id = 338
# shape = (50, 6)
# window_id = 339
# shape = (50, 6)
# window_id = 340
# shape = (50, 6)
# window_id = 341
# shape = (50, 6)
# window_id = 342
# shape = (50, 6)
# window_id = 343
# shape = (50, 6)
# window_id = 344
# shape = (50, 6)
# window_id = 345
# shape = (50, 6)
# window_id = 346
# shape = (50, 6)
# window_id = 347
# shape = (50, 6)
# window_id = 348
# shape = (50, 6)
# window_id = 349
# shape = (50, 6)
# window_id = 350
# shape = (50, 6)
# window_id = 351
# shape = (50, 6)
# window_id = 352
# shape = (50, 6)
# window_id = 353
# shape = (50, 6)
# window_id = 354
# shape = (50, 6)
# window_id = 355
# shape = (50, 6)
# window_id = 356
# shape = (50, 6)
# window_id = 357
# shape = (50, 6)
# window_id = 358
# shape = (50, 6)
# window_id = 359
# shape = (50, 6)
# window_id = 360
# shape = (50, 6)
# window_id = 361
# shape = (50, 6)
# window_id = 362
# shape = (50, 6)
# window_id = 363
# shape = (50, 6)
# window_id = 364
# shape = (50, 6)
# window_id = 365
# shape = (50, 6)
# window_id = 366
# shape = (50, 6)
# window_id = 367
# shape = (50, 6)
# window_id = 368
# shape = (50, 6)
# window_id = 369
# shape = (50, 6)
# window_id = 370
# shape = (50, 6)
# window_id = 371
# shape = (50, 6)
# window_id = 372
# shape = (50, 6)
# window_id = 373
# shape = (50, 6)
# window_id = 374
# shape = (50, 6)
# window_id = 375
# shape = (50, 6)
# window_id = 376
# shape = (50, 6)
# window_id = 377
# shape = (50, 6)
# window_id = 378
# shape = (50, 6)
# window_id = 379
# shape = (50, 6)
# window_id = 380
# shape = (50, 6)
# window_id = 381
# shape = (50, 6)
# window_id = 382
# shape = (50, 6)
# window_id = 383
# shape = (50, 6)
# window_id = 384
# shape = (50, 6)
# window_id = 385
# shape = (50, 6)
# window_id = 386
# shape = (50, 6)
# window_id = 387
# shape = (50, 6)
# window_id = 388
# shape = (50, 6)
# window_id = 389
# shape = (50, 6)
# window_id = 390
# shape = (50, 6)
# window_id = 391
# shape = (50, 6)
# window_id = 392
# shape = (50, 6)
# window_id = 393
# shape = (50, 6)
# window_id = 394
# shape = (50, 6)
# window_id = 395
# shape = (50, 6)
# window_id = 396
# shape = (50, 6)
# window_id = 397
# shape = (50, 6)
# window_id = 398
# shape = (50, 6)
# window_id = 399
# shape = (50, 6)
# window_id = 400
# shape = (50, 6)
# window_id = 401
# shape = (50, 6)
# window_id = 402
# shape = (50, 6)
# window_id = 403
# shape = (50, 6)
# window_id = 404
# shape = (50, 6)
# window_id = 405
# shape = (50, 6)
# window_id = 406
# shape = (50, 6)
# window_id = 407
# shape = (50, 6)
# window_id = 408
# shape = (50, 6)
# window_id = 409
# shape = (50, 6)
# window_id = 410
# shape = (50, 6)
# window_id = 411
# shape = (50, 6)
# window_id = 412
# shape = (50, 6)
# window_id = 413
# shape = (50, 6)
# window_id = 414
# shape = (50, 6)
# window_id = 415
# shape = (50, 6)
# window_id = 416
# shape = (50, 6)
# window_id = 417
# shape = (50, 6)
# window_id = 418
# shape = (50, 6)
# window_id = 419
# shape = (50, 6)
# window_id = 420
# shape = (50, 6)
# window_id = 421
# shape = (50, 6)
# window_id = 422
# shape = (50, 6)
# window_id = 423
# shape = (50, 6)
# window_id = 424
# shape = (50, 6)
# window_id = 425
# shape = (50, 6)
# window_id = 426
# shape = (50, 6)
# window_id = 427
# shape = (50, 6)
# window_id = 428
# shape = (50, 6)
# window_id = 429
# shape = (50, 6)
# window_id = 430
# shape = (50, 6)
# window_id = 431
# shape = (50, 6)
# window_id = 432
# shape = (50, 6)
# window_id = 433
# shape = (50, 6)
# window_id = 434
# shape = (50, 6)
# window_id = 435
# shape = (50, 6)
# window_id = 436
# shape = (50, 6)
# window_id = 437
# shape = (50, 6)
# window_id = 438
# shape = (50, 6)
# window_id = 439
# shape = (50, 6)
# window_id = 440
# shape = (50, 6)
# window_id = 441
# shape = (50, 6)
# window_id = 442
# shape = (50, 6)
# window_id = 443
# shape = (50, 6)
# window_id = 444
# shape = (50, 6)
# window_id = 445
# shape = (50, 6)
# window_id = 446
# shape = (50, 6)
# window_id = 447
# shape = (50, 6)
# window_id = 448
# shape = (50, 6)
# window_id = 449
# shape = (50, 6)
# window_id = 450
# shape = (50, 6)
# window_id = 451
# shape = (50, 6)
# window_id = 452
# shape = (50, 6)
# window_id = 453
# shape = (50, 6)
# window_id = 454
# shape = (50, 6)
# window_id = 455
# shape = (50, 6)
# window_id = 456
# shape = (50, 6)
# window_id = 457
# shape = (50, 6)
# window_id = 458
# shape = (50, 6)
# window_id = 459
# shape = (50, 6)
# window_id = 460
# shape = (50, 6)
# window_id = 461
# shape = (50, 6)
# window_id = 462
# shape = (50, 6)
# window_id = 463
# shape = (50, 6)
# window_id = 464
# shape = (50, 6)
# window_id = 465
# shape = (50, 6)
# window_id = 466
# shape = (50, 6)
# window_id = 467
# shape = (50, 6)
# window_id = 468
# shape = (50, 6)
# window_id = 469
# shape = (50, 6)
# window_id = 470
# shape = (50, 6)
# window_id = 471
# shape = (50, 6)
# window_id = 472
# shape = (50, 6)
# window_id = 473
# shape = (50, 6)
# window_id = 474
# shape = (50, 6)
# window_id = 475
# shape = (50, 6)
# window_id = 476
# shape = (50, 6)
# window_id = 477
# shape = (50, 6)
# window_id = 478
# shape = (50, 6)
# window_id = 479
# shape = (50, 6)
# window_id = 480
# shape = (50, 6)
# window_id = 481
# shape = (50, 6)
# window_id = 482
# shape = (50, 6)
# window_id = 483
# shape = (50, 6)
# window_id = 484
# shape = (50, 6)
# window_id = 485
# shape = (50, 6)
# window_id = 486
# shape = (50, 6)
# window_id = 487
# shape = (50, 6)
# window_id = 488
# shape = (50, 6)
# window_id = 489
# shape = (50, 6)
# window_id = 490
# shape = (50, 6)
# window_id = 491
# shape = (50, 6)
# window_id = 492
# shape = (50, 6)
# window_id = 493
# shape = (50, 6)
# window_id = 494
# shape = (50, 6)
# window_id = 495
# shape = (50, 6)
# window_id = 496
# shape = (50, 6)
# window_id = 497
# shape = (50, 6)
# window_id = 498
# shape = (50, 6)
# window_id = 499
# shape = (50, 6)
# window_id = 500
# shape = (50, 6)
# window_id = 501
# shape = (50, 6)
# window_id = 502
# shape = (50, 6)
# window_id = 503
# shape = (50, 6)
# window_id = 504
# shape = (50, 6)
# window_id = 505
# shape = (50, 6)
# window_id = 506
# shape = (50, 6)
# window_id = 507
# shape = (50, 6)
# window_id = 508
# shape = (50, 6)
# window_id = 509
# shape = (50, 6)
# window_id = 510
# shape = (50, 6)
# window_id = 511
# shape = (50, 6)
# window_id = 512
# shape = (50, 6)
# window_id = 513
# shape = (50, 6)
# window_id = 514
# shape = (50, 6)
# window_id = 515
# shape = (50, 6)
# window_id = 516
# shape = (50, 6)
# window_id = 517
# shape = (50, 6)
# window_id = 518
# shape = (50, 6)
# window_id = 519
# shape = (50, 6)
# window_id = 520
# shape = (50, 6)
# window_id = 521
# shape = (50, 6)
# window_id = 522
# shape = (50, 6)
# window_id = 523
# shape = (50, 6)
# window_id = 524
# shape = (50, 6)
# window_id = 525
# shape = (50, 6)
# window_id = 526
# shape = (50, 6)
# window_id = 527
# shape = (50, 6)
# window_id = 528
# shape = (50, 6)
# window_id = 529
# shape = (50, 6)
# window_id = 530
# shape = (50, 6)
# window_id = 531
# shape = (50, 6)
# window_id = 532
# shape = (50, 6)
# window_id = 533
# shape = (50, 6)
# window_id = 534
# shape = (50, 6)
# window_id = 535
# shape = (50, 6)
# window_id = 536
# shape = (50, 6)
# window_id = 537
# shape = (50, 6)
# window_id = 538
# shape = (50, 6)
# window_id = 539
# shape = (50, 6)
# window_id = 540
# shape = (50, 6)
# window_id = 541
# shape = (50, 6)
# window_id = 542
# shape = (50, 6)
# window_id = 543
# shape = (50, 6)
# window_id = 544
# shape = (50, 6)
# window_id = 545
# shape = (50, 6)
# window_id = 546
# shape = (50, 6)
# window_id = 547
# shape = (50, 6)
# window_id = 548
# shape = (50, 6)
# window_id = 549
# shape = (50, 6)
# window_id = 550
# shape = (50, 6)
# window_id = 551
# shape = (50, 6)
# window_id = 552
# shape = (50, 6)
# window_id = 553
# shape = (50, 6)
# window_id = 554
# shape = (50, 6)
# window_id = 555
# shape = (50, 6)
# window_id = 556
# shape = (50, 6)
# window_id = 557
# shape = (50, 6)
# window_id = 558
# shape = (50, 6)
# window_id = 559
# shape = (50, 6)
# window_id = 560
# shape = (50, 6)
# window_id = 561
# shape = (50, 6)
# window_id = 562
# shape = (50, 6)
# window_id = 563
# shape = (50, 6)
# window_id = 564
# shape = (50, 6)
# window_id = 565
# shape = (50, 6)
# window_id = 566
# shape = (50, 6)
# window_id = 567
# shape = (50, 6)
# window_id = 568
# shape = (50, 6)
# window_id = 569
# shape = (50, 6)
# window_id = 570
# shape = (50, 6)
# window_id = 571
# shape = (50, 6)
# window_id = 572
# shape = (50, 6)
# window_id = 573
# shape = (50, 6)
# window_id = 574
# shape = (50, 6)
# window_id = 575
# shape = (50, 6)
# window_id = 576
# shape = (50, 6)
# window_id = 577
# shape = (50, 6)
# window_id = 578
# shape = (50, 6)
# window_id = 579
# shape = (50, 6)
# window_id = 580
# shape = (50, 6)
# window_id = 581
# shape = (50, 6)
# window_id = 582
# shape = (50, 6)
# window_id = 583
# shape = (50, 6)
# window_id = 584
# shape = (50, 6)
# window_id = 585
# shape = (50, 6)
# window_id = 586
# shape = (50, 6)
# window_id = 587
# shape = (50, 6)
# window_id = 588
# shape = (50, 6)
# window_id = 589
# shape = (50, 6)
# window_id = 590
# shape = (50, 6)
# window_id = 591
# shape = (50, 6)
# window_id = 592
# shape = (50, 6)
# window_id = 593
# shape = (50, 6)
# window_id = 594
# shape = (50, 6)
# window_id = 595
# shape = (50, 6)
# window_id = 596
# shape = (50, 6)
# window_id = 597
# shape = (50, 6)
# window_id = 598
# shape = (50, 6)
# window_id = 599
# shape = (50, 6)
# window_id = 600
# shape = (50, 6)
# window_id = 601
# shape = (50, 6)
# window_id = 602
# shape = (50, 6)
# window_id = 603
# shape = (50, 6)
# window_id = 604
# shape = (50, 6)
# window_id = 605
# shape = (50, 6)
# window_id = 606
# shape = (50, 6)
# window_id = 607
# shape = (50, 6)
# window_id = 608
# shape = (50, 6)
# window_id = 609
# shape = (50, 6)
# window_id = 610
# shape = (50, 6)
# window_id = 611
# shape = (50, 6)
# window_id = 612
# shape = (50, 6)
# window_id = 613
# shape = (50, 6)
# window_id = 614
# shape = (50, 6)
# window_id = 615
# shape = (50, 6)
# window_id = 616
# shape = (50, 6)
# window_id = 617
# shape = (50, 6)
# window_id = 618
# shape = (50, 6)
# window_id = 619
# shape = (50, 6)
# window_id = 620
# shape = (50, 6)
# window_id = 621
# shape = (50, 6)
# window_id = 622
# shape = (50, 6)
# window_id = 623
# shape = (50, 6)
# window_id = 624
# shape = (50, 6)
# window_id = 625
# shape = (50, 6)
# window_id = 626
# shape = (50, 6)
# window_id = 627
# shape = (50, 6)
# window_id = 628
# shape = (50, 6)
# window_id = 629
# shape = (50, 6)
# window_id = 630
# shape = (50, 6)
# window_id = 631
# shape = (50, 6)
# window_id = 632
# shape = (50, 6)
# window_id = 633
# shape = (50, 6)
# window_id = 634
# shape = (50, 6)
# window_id = 635
# shape = (50, 6)
# window_id = 636
# shape = (50, 6)
# window_id = 637
# shape = (50, 6)
# window_id = 638
# shape = (50, 6)
# window_id = 639
# shape = (50, 6)
# window_id = 640
# shape = (50, 6)
# window_id = 641
# shape = (50, 6)
# window_id = 642
# shape = (50, 6)
# window_id = 643
# shape = (50, 6)
# window_id = 644
# shape = (50, 6)
# window_id = 645
# shape = (50, 6)
# window_id = 646
# shape = (50, 6)
# window_id = 647
# shape = (50, 6)
# window_id = 648
# shape = (50, 6)
# window_id = 649
# shape = (50, 6)
# window_id = 650
# shape = (50, 6)
# window_id = 651
# shape = (50, 6)
# window_id = 652
# shape = (50, 6)
# window_id = 653
# shape = (50, 6)
# window_id = 654
# shape = (50, 6)
# window_id = 655
# shape = (50, 6)
# window_id = 656
# shape = (50, 6)
# window_id = 657
# shape = (50, 6)
# window_id = 658
# shape = (50, 6)
# window_id = 659
# shape = (50, 6)
# window_id = 660
# shape = (50, 6)
# window_id = 661
# shape = (50, 6)
# window_id = 662
# shape = (50, 6)
# window_id = 663
# shape = (50, 6)
# window_id = 664
# shape = (50, 6)
# window_id = 665
# shape = (50, 6)
# window_id = 666
# shape = (50, 6)
# window_id = 667
# shape = (50, 6)
# window_id = 668
# shape = (50, 6)
# window_id = 669
# shape = (50, 6)
# window_id = 670
# shape = (50, 6)
# window_id = 671
# shape = (50, 6)
# window_id = 672
# shape = (50, 6)
# window_id = 673
# shape = (50, 6)
# window_id = 674
# shape = (50, 6)
# window_id = 675
# shape = (50, 6)
# window_id = 676
# shape = (50, 6)
# window_id = 677
# shape = (50, 6)
# window_id = 678
# shape = (50, 6)
# window_id = 679
# shape = (50, 6)
# window_id = 680
# shape = (50, 6)
# window_id = 681
# shape = (50, 6)
# window_id = 682
# shape = (50, 6)
# window_id = 683
# shape = (50, 6)
# window_id = 684
# shape = (50, 6)
# window_id = 685
# shape = (50, 6)
# window_id = 686
# shape = (50, 6)
# window_id = 687
# shape = (50, 6)
# window_id = 688
# shape = (50, 6)
# window_id = 689
# shape = (50, 6)
# window_id = 690
# shape = (50, 6)
# window_id = 691
# shape = (50, 6)
# window_id = 692
# shape = (50, 6)
# window_id = 693
# shape = (50, 6)
# window_id = 694
# shape = (50, 6)
# window_id = 695
# shape = (50, 6)
# window_id = 696
# shape = (50, 6)
# window_id = 697
# shape = (50, 6)
# window_id = 698
# shape = (50, 6)
# window_id = 699
# shape = (50, 6)
# window_id = 700
# shape = (50, 6)
# window_id = 701
# shape = (50, 6)
# window_id = 702
# shape = (50, 6)
# window_id = 703
# shape = (50, 6)
# window_id = 704
# shape = (50, 6)
# window_id = 705
# shape = (50, 6)
# window_id = 706
# shape = (50, 6)
# window_id = 707
# shape = (50, 6)
# window_id = 708
# shape = (50, 6)
# window_id = 709
# shape = (50, 6)
# window_id = 710
# shape = (50, 6)
# window_id = 711
# shape = (50, 6)
# window_id = 712
# shape = (50, 6)
# window_id = 713
# shape = (50, 6)
# window_id = 714
# shape = (50, 6)
# window_id = 715
# shape = (50, 6)
# window_id = 716
# shape = (50, 6)
# window_id = 717
# shape = (50, 6)
# window_id = 718
# shape = (50, 6)
# window_id = 719
# shape = (50, 6)
# window_id = 720
# shape = (50, 6)
# window_id = 721
# shape = (50, 6)
# window_id = 722
# shape = (50, 6)
# window_id = 723
# shape = (50, 6)
# window_id = 724
# shape = (50, 6)
# window_id = 725
# shape = (50, 6)
# window_id = 726
# shape = (50, 6)
# window_id = 727
# shape = (50, 6)
# window_id = 728
# shape = (50, 6)
# window_id = 729
# shape = (50, 6)
# window_id = 730
# shape = (50, 6)
# window_id = 731
# shape = (50, 6)
# window_id = 732
# shape = (50, 6)
# window_id = 733
# shape = (50, 6)
# window_id = 734
# shape = (50, 6)
# window_id = 735
# shape = (50, 6)
# window_id = 736
# shape = (50, 6)
# window_id = 737
# shape = (50, 6)
# window_id = 738
# shape = (50, 6)
# window_id = 739
# shape = (50, 6)
# window_id = 740
# shape = (50, 6)
# window_id = 741
# shape = (50, 6)
# window_id = 742
# shape = (50, 6)
# window_id = 743
# shape = (50, 6)
# window_id = 744
# shape = (50, 6)
# window_id = 745
# shape = (50, 6)
# window_id = 746
# shape = (50, 6)
# window_id = 747
# shape = (50, 6)
# window_id = 748
# shape = (50, 6)
# window_id = 749
# shape = (50, 6)
# window_id = 750
# shape = (50, 6)
# window_id = 751
# shape = (50, 6)
# window_id = 752
# shape = (50, 6)
# window_id = 753
# shape = (50, 6)
# window_id = 754
# shape = (50, 6)
# window_id = 755
# shape = (50, 6)
# window_id = 756
# shape = (50, 6)
# window_id = 757
# shape = (50, 6)
# window_id = 758
# shape = (50, 6)
# window_id = 759
# shape = (50, 6)
# window_id = 760
# shape = (50, 6)
# window_id = 761
# shape = (50, 6)
# window_id = 762
# shape = (50, 6)
# window_id = 763
# shape = (50, 6)
# window_id = 764
# shape = (50, 6)
# window_id = 765
# shape = (50, 6)
# window_id = 766
# shape = (50, 6)
# window_id = 767
# shape = (50, 6)
# window_id = 768
# shape = (50, 6)
# window_id = 769
# shape = (50, 6)
# window_id = 770
# shape = (50, 6)
# window_id = 771
# shape = (50, 6)
# window_id = 772
# shape = (50, 6)
# window_id = 773
# shape = (50, 6)
# window_id = 774
# shape = (50, 6)
# window_id = 775
# shape = (50, 6)
# window_id = 776
# shape = (50, 6)
# window_id = 777
# shape = (50, 6)
# window_id = 778
# shape = (50, 6)
# window_id = 779
# shape = (50, 6)
# window_id = 780
# shape = (50, 6)
# window_id = 781
# shape = (50, 6)
# window_id = 782
# shape = (50, 6)
# window_id = 783
# shape = (50, 6)
# window_id = 784
# shape = (50, 6)
# window_id = 785
# shape = (50, 6)
# window_id = 786
# shape = (50, 6)
# window_id = 787
# shape = (50, 6)
# window_id = 788
# shape = (50, 6)
# window_id = 789
# shape = (50, 6)
# window_id = 790
# shape = (50, 6)
# window_id = 791
# shape = (50, 6)
# window_id = 792
# shape = (50, 6)
# window_id = 793
# shape = (50, 6)
# window_id = 794
# shape = (50, 6)
# window_id = 795
# shape = (50, 6)
# window_id = 796
# shape = (50, 6)
# window_id = 797
# shape = (50, 6)
# window_id = 798
# shape = (50, 6)
# window_id = 799
# shape = (50, 6)
# window_id = 800
# shape = (50, 6)
# window_id = 801
# shape = (50, 6)
# window_id = 802
# shape = (50, 6)
# window_id = 803
# shape = (50, 6)
# window_id = 804
# shape = (50, 6)
# window_id = 805
# shape = (50, 6)
# window_id = 806
# shape = (50, 6)
# window_id = 807
# shape = (50, 6)
# window_id = 808
# shape = (50, 6)
# window_id = 809
# shape = (50, 6)
# window_id = 810
# shape = (50, 6)
# window_id = 811
# shape = (50, 6)
# window_id = 812
# shape = (50, 6)
# window_id = 813
# shape = (50, 6)
# window_id = 814
# shape = (50, 6)
# window_id = 815
# shape = (50, 6)
# window_id = 816
# shape = (50, 6)
# window_id = 817
# shape = (50, 6)
# window_id = 818
# shape = (50, 6)
# window_id = 819
# shape = (50, 6)
# window_id = 820
# shape = (50, 6)
# window_id = 821
# shape = (50, 6)
# window_id = 822
# shape = (50, 6)
# window_id = 823
# shape = (50, 6)
# window_id = 824
# shape = (50, 6)
# window_id = 825
# shape = (50, 6)
# window_id = 826
# shape = (50, 6)
# window_id = 827
# shape = (50, 6)
# window_id = 828
# shape = (50, 6)
# window_id = 829
# shape = (50, 6)
# window_id = 830
# shape = (50, 6)
# window_id = 831
# shape = (50, 6)
# window_id = 832
# shape = (50, 6)
# window_id = 833
# shape = (50, 6)
# window_id = 834
# shape = (50, 6)
# window_id = 835
# shape = (50, 6)
# window_id = 836
# shape = (50, 6)
# window_id = 837
# shape = (50, 6)
# window_id = 838
# shape = (50, 6)
# window_id = 839
# shape = (50, 6)
# window_id = 840
# shape = (50, 6)
# window_id = 841
# shape = (50, 6)
# window_id = 842
# shape = (50, 6)
# window_id = 843
# shape = (50, 6)
# window_id = 844
# shape = (50, 6)
# window_id = 845
# shape = (50, 6)
# window_id = 846
# shape = (50, 6)
# window_id = 847
# shape = (50, 6)
# window_id = 848
# shape = (50, 6)
# window_id = 849
# shape = (50, 6)
# window_id = 850
# shape = (50, 6)
# window_id = 851
# shape = (50, 6)
# window_id = 852
# shape = (50, 6)
# window_id = 853
# shape = (50, 6)
# window_id = 854
# shape = (50, 6)
# window_id = 855
# shape = (50, 6)
# window_id = 856
# shape = (50, 6)
# window_id = 857
# shape = (50, 6)
# window_id = 858
# shape = (50, 6)
# window_id = 859
# shape = (50, 6)
# window_id = 860
# shape = (50, 6)
# window_id = 861
# shape = (50, 6)
# window_id = 862
# shape = (50, 6)
# window_id = 863
# shape = (50, 6)
# window_id = 864
# shape = (50, 6)
# window_id = 865
# shape = (50, 6)
# window_id = 866
# shape = (50, 6)
# window_id = 867
# shape = (50, 6)
# window_id = 868
# shape = (50, 6)
# window_id = 869
# shape = (50, 6)
# window_id = 870
# shape = (50, 6)
# window_id = 871
# shape = (50, 6)
# window_id = 872
# shape = (50, 6)
# window_id = 873
# shape = (50, 6)
# window_id = 874
# shape = (50, 6)
# window_id = 875
# shape = (50, 6)
# window_id = 876
# shape = (50, 6)
# window_id = 877
# shape = (50, 6)
# window_id = 878
# shape = (50, 6)
# window_id = 879
# shape = (50, 6)
# window_id = 880
# shape = (50, 6)
# window_id = 881
# shape = (50, 6)
# window_id = 882
# shape = (50, 6)
# window_id = 883
# shape = (50, 6)
# window_id = 884
# shape = (50, 6)
# window_id = 885
# shape = (50, 6)
# window_id = 886
# shape = (50, 6)
# window_id = 887
# shape = (50, 6)
# window_id = 888
# shape = (50, 6)
# window_id = 889
# shape = (50, 6)
# window_id = 890
# shape = (50, 6)
# window_id = 891
# shape = (50, 6)
# window_id = 892
# shape = (50, 6)
# window_id = 893
# shape = (50, 6)
# window_id = 894
# shape = (50, 6)
# window_id = 895
# shape = (50, 6)
# window_id = 896
# shape = (50, 6)
# window_id = 897
# shape = (50, 6)
# window_id = 898
# shape = (50, 6)
# window_id = 899
# shape = (50, 6)
# window_id = 900
# shape = (50, 6)
# window_id = 901
# shape = (50, 6)
# window_id = 902
# shape = (50, 6)
# window_id = 903
# shape = (50, 6)
# window_id = 904
# shape = (50, 6)
# window_id = 905
# shape = (50, 6)
# window_id = 906
# shape = (50, 6)
# window_id = 907
# shape = (50, 6)
# window_id = 908
# shape = (50, 6)
# window_id = 909
# shape = (50, 6)
# window_id = 910
# shape = (50, 6)
# window_id = 911
# shape = (50, 6)
# window_id = 912
# shape = (50, 6)
# window_id = 913
# shape = (50, 6)
# window_id = 914
# shape = (50, 6)
# window_id = 915
# shape = (50, 6)
# window_id = 916
# shape = (50, 6)
# window_id = 917
# shape = (50, 6)
# window_id = 918
# shape = (50, 6)
# window_id = 919
# shape = (50, 6)
# window_id = 920
# shape = (50, 6)
# window_id = 921
# shape = (50, 6)
# window_id = 922
# shape = (50, 6)
# window_id = 923
# shape = (50, 6)
# window_id = 924
# shape = (50, 6)
# window_id = 925
# shape = (50, 6)
# window_id = 926
# shape = (50, 6)
# window_id = 927
# shape = (50, 6)
# window_id = 928
# shape = (50, 6)
# window_id = 929
# shape = (50, 6)
# window_id = 930
# shape = (50, 6)
# window_id = 931
# shape = (50, 6)
# window_id = 932
# shape = (50, 6)
# window_id = 933
# shape = (50, 6)
# window_id = 934
# shape = (50, 6)
# window_id = 935
# shape = (50, 6)
# window_id = 936
# shape = (50, 6)
# window_id = 937
# shape = (50, 6)
# window_id = 938
# shape = (50, 6)
# window_id = 939
# shape = (50, 6)
# window_id = 940
# shape = (50, 6)
# window_id = 941
# shape = (50, 6)
# window_id = 942
# shape = (50, 6)
# window_id = 943
# shape = (50, 6)
# window_id = 944
# shape = (50, 6)
# window_id = 945
# shape = (50, 6)
# window_id = 946
# shape = (50, 6)
# window_id = 947
# shape = (50, 6)
# window_id = 948
# shape = (50, 6)
# window_id = 949
# shape = (50, 6)
# window_id = 950
# shape = (50, 6)
# window_id = 951
# shape = (50, 6)
# window_id = 952
# shape = (50, 6)
# window_id = 953
# shape = (50, 6)
# window_id = 954
# shape = (50, 6)
# window_id = 955
# shape = (50, 6)
# window_id = 956
# shape = (50, 6)
# window_id = 957
# shape = (50, 6)
# window_id = 958
# shape = (50, 6)
# window_id = 959
# shape = (50, 6)
# window_id = 960
# shape = (50, 6)
# window_id = 961
# shape = (50, 6)
# window_id = 962
# shape = (50, 6)
# window_id = 963
# shape = (50, 6)
# window_id = 964
# shape = (50, 6)
# window_id = 965
# shape = (50, 6)
# window_id = 966
# shape = (50, 6)
# window_id = 967
# shape = (50, 6)
# window_id = 968
# shape = (50, 6)
# window_id = 969
# shape = (50, 6)
# window_id = 970
# shape = (50, 6)
# window_id = 971
# shape = (50, 6)
# window_id = 972
# shape = (50, 6)
# window_id = 973
# shape = (50, 6)
# window_id = 974
# shape = (50, 6)
# window_id = 975
# shape = (50, 6)
# window_id = 976
# shape = (50, 6)
# window_id = 977
# shape = (50, 6)
# window_id = 978
# shape = (50, 6)
# window_id = 979
# shape = (50, 6)
# window_id = 980
# shape = (50, 6)
# window_id = 981
# shape = (50, 6)
# window_id = 982
# shape = (50, 6)
# window_id = 983
# shape = (50, 6)
# window_id = 984
# shape = (50, 6)
# window_id = 985
# shape = (50, 6)
# window_id = 986
# shape = (50, 6)
# window_id = 987
# shape = (50, 6)
# window_id = 988
# shape = (50, 6)
# window_id = 989
# shape = (50, 6)
# window_id = 990
# shape = (50, 6)
# window_id = 991
# shape = (50, 6)
# window_id = 992
# shape = (50, 6)
# window_id = 993
# shape = (50, 6)
# window_id = 994
# shape = (50, 6)
# window_id = 995
# shape = (50, 6)
# window_id = 996
# shape = (50, 6)
# window_id = 997
# shape = (50, 6)
# window_id = 998
# shape = (50, 6)
# window_id = 999
# shape = (50, 6)
# window_id = 1000
# shape = (50, 6)
# window_id = 1001
# shape = (50, 6)
# window_id = 1002
# shape = (50, 6)
# window_id = 1003
# shape = (50, 6)
# window_id = 1004
# shape = (50, 6)
# window_id = 1005
# shape = (50, 6)
# window_id = 1006
# shape = (50, 6)
# window_id = 1007
# shape = (50, 6)
# window_id = 1008
# shape = (50, 6)
# window_id = 1009
# shape = (50, 6)
# window_id = 1010
# shape = (50, 6)
# window_id = 1011
# shape = (50, 6)
# window_id = 1012
# shape = (50, 6)
# window_id = 1013
# shape = (50, 6)
# window_id = 1014
# shape = (50, 6)
# window_id = 1015
# shape = (50, 6)
# window_id = 1016
# shape = (50, 6)
# window_id = 1017
# shape = (50, 6)
# window_id = 1018
# shape = (50, 6)
# window_id = 1019
# shape = (50, 6)
# window_id = 1020
# shape = (50, 6)
# window_id = 1021
# shape = (50, 6)
# window_id = 1022
# shape = (50, 6)
# window_id = 1023
# shape = (50, 6)
# window_id = 1024
# shape = (50, 6)
# window_id = 1025
# shape = (50, 6)
# window_id = 1026
# shape = (50, 6)
# window_id = 1027
# shape = (50, 6)
# window_id = 1028
# shape = (50, 6)
# window_id = 1029
# shape = (50, 6)
# window_id = 1030
# shape = (50, 6)
# window_id = 1031
# shape = (50, 6)
# window_id = 1032
# shape = (50, 6)
# window_id = 1033
# shape = (50, 6)
# window_id = 1034
# shape = (50, 6)
# window_id = 1035
# shape = (50, 6)
# window_id = 1036
# shape = (50, 6)
# window_id = 1037
# shape = (50, 6)
# window_id = 1038
# shape = (50, 6)
# window_id = 1039
# shape = (50, 6)
# window_id = 1040
# shape = (50, 6)
# window_id = 1041
# shape = (50, 6)
# window_id = 1042
# shape = (50, 6)
# window_id = 1043
# shape = (50, 6)
# window_id = 1044
# shape = (50, 6)
# window_id = 1045
# shape = (50, 6)
# window_id = 1046
# shape = (50, 6)
# window_id = 1047
# shape = (50, 6)
# window_id = 1048
# shape = (50, 6)
# window_id = 1049
# shape = (50, 6)
# window_id = 1050
# shape = (50, 6)
# window_id = 1051
# shape = (50, 6)
# window_id = 1052
# shape = (50, 6)
# window_id = 1053
# shape = (50, 6)
# window_id = 1054
# shape = (50, 6)
# window_id = 1055
# shape = (50, 6)
# window_id = 1056
# shape = (50, 6)
# window_id = 1057
# shape = (50, 6)
# window_id = 1058
# shape = (50, 6)
# window_id = 1059
# shape = (50, 6)
# window_id = 1060
# shape = (50, 6)
# window_id = 1061
# shape = (50, 6)
# window_id = 1062
# shape = (50, 6)
# window_id = 1063
# shape = (50, 6)
# window_id = 1064
# shape = (50, 6)
# window_id = 1065
# shape = (50, 6)
# window_id = 1066
# shape = (50, 6)
# window_id = 1067
# shape = (50, 6)
# window_id = 1068
# shape = (50, 6)
# window_id = 1069
# shape = (50, 6)
# window_id = 1070
# shape = (50, 6)
# window_id = 1071
# shape = (50, 6)
# window_id = 1072
# shape = (50, 6)
# window_id = 1073
# shape = (50, 6)
# window_id = 1074
# shape = (50, 6)
# window_id = 1075
# shape = (50, 6)
# window_id = 1076
# shape = (50, 6)
# window_id = 1077
# shape = (50, 6)
# window_id = 1078
# shape = (50, 6)
# window_id = 1079
# shape = (50, 6)
# window_id = 1080
# shape = (50, 6)
# window_id = 1081
# shape = (50, 6)
# window_id = 1082
# shape = (50, 6)
# window_id = 1083
# shape = (50, 6)
# window_id = 1084
# shape = (50, 6)
# window_id = 1085
# shape = (50, 6)
# window_id = 1086
# shape = (50, 6)
# window_id = 1087
# shape = (50, 6)
# window_id = 1088
# shape = (50, 6)
# window_id = 1089
# shape = (50, 6)
# window_id = 1090
# shape = (50, 6)
# window_id = 1091
# shape = (50, 6)
# window_id = 1092
# shape = (50, 6)
# window_id = 1093
# shape = (50, 6)
# window_id = 1094
# shape = (50, 6)
# window_id = 1095
# shape = (50, 6)
# window_id = 1096
# shape = (50, 6)
# window_id = 1097
# shape = (50, 6)
# window_id = 1098
# shape = (50, 6)
# window_id = 1099
# shape = (50, 6)
# window_id = 1100
# shape = (50, 6)
# window_id = 1101
# shape = (50, 6)
# window_id = 1102
# shape = (50, 6)
# window_id = 1103
# shape = (50, 6)
# window_id = 1104
# shape = (50, 6)
# window_id = 1105
# shape = (50, 6)
# window_id = 1106
# shape = (50, 6)
# window_id = 1107
# shape = (50, 6)
# window_id = 1108
# shape = (50, 6)
# window_id = 1109
# shape = (50, 6)
# window_id = 1110
# shape = (50, 6)
# window_id = 1111
# shape = (50, 6)
# window_id = 1112
# shape = (50, 6)
# window_id = 1113
# shape = (50, 6)
# window_id = 1114
# shape = (50, 6)
# window_id = 1115
# shape = (50, 6)
# window_id = 1116
# shape = (50, 6)
# window_id = 1117
# shape = (50, 6)
# window_id = 1118
# shape = (50, 6)
# window_id = 1119
# shape = (50, 6)
# window_id = 1120
# shape = (50, 6)
# window_id = 1121
# shape = (50, 6)
# window_id = 1122
# shape = (50, 6)
# window_id = 1123
# shape = (50, 6)
# window_id = 1124
# shape = (50, 6)
# window_id = 1125
# shape = (50, 6)
# window_id = 1126
# shape = (50, 6)
# window_id = 1127
# shape = (50, 6)
# window_id = 1128
# shape = (50, 6)
# window_id = 1129
# shape = (50, 6)
# window_id = 1130
# shape = (50, 6)
# window_id = 1131
# shape = (50, 6)
# window_id = 1132
# shape = (50, 6)
# window_id = 1133
# shape = (50, 6)
# window_id = 1134
# shape = (50, 6)
# window_id = 1135
# shape = (50, 6)
# window_id = 1136
# shape = (50, 6)
# window_id = 1137
# shape = (50, 6)
# window_id = 1138
# shape = (50, 6)
# window_id = 1139
# shape = (50, 6)
# window_id = 1140
# shape = (50, 6)
# window_id = 1141
# shape = (50, 6)
# window_id = 1142
# shape = (50, 6)
# window_id = 1143
# shape = (50, 6)
# window_id = 1144
# shape = (50, 6)
# window_id = 1145
# shape = (50, 6)
# window_id = 1146
# shape = (50, 6)
# window_id = 1147
# shape = (50, 6)
# window_id = 1148
# shape = (50, 6)
# window_id = 1149
# shape = (50, 6)
# window_id = 1150
# shape = (50, 6)
# window_id = 1151
# shape = (50, 6)
# window_id = 1152
# shape = (50, 6)
# window_id = 1153
# shape = (50, 6)
# window_id = 1154
# shape = (50, 6)
# window_id = 1155
# shape = (50, 6)
# window_id = 1156
# shape = (50, 6)
# window_id = 1157
# shape = (50, 6)
# window_id = 1158
# shape = (50, 6)
# window_id = 1159
# shape = (50, 6)
# window_id = 1160
# shape = (50, 6)
# window_id = 1161
# shape = (50, 6)
# window_id = 1162
# shape = (50, 6)
# window_id = 1163
# shape = (50, 6)
# window_id = 1164
# shape = (50, 6)
# window_id = 1165
# shape = (50, 6)
# window_id = 1166
# shape = (50, 6)
# window_id = 1167
# shape = (50, 6)
# window_id = 1168
# shape = (50, 6)
# window_id = 1169
# shape = (50, 6)
# window_id = 1170
# shape = (50, 6)
# window_id = 1171
# shape = (50, 6)
# window_id = 1172
# shape = (50, 6)
# window_id = 1173
# shape = (50, 6)
# window_id = 1174
# shape = (50, 6)
# window_id = 1175
# shape = (50, 6)
# window_id = 1176
# shape = (50, 6)
# window_id = 1177
# shape = (50, 6)
# window_id = 1178
# shape = (50, 6)
# window_id = 1179
# shape = (50, 6)
# window_id = 1180
# shape = (50, 6)
# window_id = 1181
# shape = (50, 6)
# window_id = 1182
# shape = (50, 6)
# window_id = 1183
# shape = (50, 6)
# window_id = 1184
# shape = (50, 6)
# window_id = 1185
# shape = (50, 6)
# window_id = 1186
# shape = (50, 6)
# window_id = 1187
# shape = (50, 6)
# window_id = 1188
# shape = (50, 6)
# window_id = 1189
# shape = (50, 6)
# window_id = 1190
# shape = (50, 6)
# window_id = 1191
# shape = (50, 6)
# window_id = 1192
# shape = (50, 6)
# window_id = 1193
# shape = (50, 6)
# window_id = 1194
# shape = (50, 6)
# window_id = 1195
# shape = (50, 6)
# window_id = 1196
# shape = (50, 6)
# window_id = 1197
# shape = (50, 6)
# window_id = 1198
# shape = (50, 6)
# window_id = 1199
# shape = (50, 6)
# window_id = 1200
# shape = (50, 6)
# window_id = 1201
# shape = (50, 6)
# window_id = 1202
# shape = (50, 6)
# window_id = 1203
# shape = (50, 6)
# window_id = 1204
# shape = (50, 6)
# window_id = 1205
# shape = (50, 6)
# window_id = 1206
# shape = (50, 6)
# window_id = 1207
# shape = (50, 6)
# window_id = 1208
# shape = (50, 6)
# window_id = 1209
# shape = (50, 6)
# window_id = 1210
# shape = (50, 6)
# window_id = 1211
# shape = (50, 6)
# window_id = 1212
# shape = (50, 6)
# window_id = 1213
# shape = (50, 6)
# window_id = 1214
# shape = (50, 6)
# window_id = 1215
# shape = (50, 6)
# window_id = 1216
# shape = (50, 6)
# window_id = 1217
# shape = (50, 6)
# window_id = 1218
# shape = (50, 6)
# window_id = 1219
# shape = (50, 6)
# window_id = 1220
# shape = (50, 6)
# window_id = 1221
# shape = (50, 6)
# window_id = 1222
# shape = (50, 6)
# window_id = 1223
# shape = (50, 6)
# window_id = 1224
# shape = (50, 6)
# window_id = 1225
# shape = (50, 6)
# window_id = 1226
# shape = (50, 6)
# window_id = 1227
# shape = (50, 6)
# window_id = 1228
# shape = (50, 6)
# window_id = 1229
# shape = (50, 6)
# window_id = 1230
# shape = (50, 6)
# window_id = 1231
# shape = (50, 6)
# window_id = 1232
# shape = (50, 6)
# window_id = 1233
# shape = (50, 6)
# window_id = 1234
# shape = (50, 6)
# window_id = 1235
# shape = (50, 6)
# window_id = 1236
# shape = (50, 6)
# window_id = 1237
# shape = (50, 6)
# window_id = 1238
# shape = (50, 6)
# window_id = 1239
# shape = (50, 6)
# window_id = 1240
# shape = (50, 6)
# window_id = 1241
# shape = (50, 6)
# window_id = 1242
# shape = (50, 6)
# window_id = 1243
# shape = (50, 6)
# window_id = 1244
# shape = (50, 6)
# window_id = 1245
# shape = (50, 6)
# window_id = 1246
# shape = (50, 6)
# window_id = 1247
# shape = (50, 6)
# window_id = 1248
# shape = (50, 6)
# window_id = 1249
# shape = (50, 6)
# window_id = 1250
# shape = (50, 6)
# window_id = 1251
# shape = (50, 6)
# window_id = 1252
# shape = (50, 6)
# window_id = 1253
# shape = (50, 6)
# window_id = 1254
# shape = (50, 6)
# window_id = 1255
# shape = (50, 6)
# window_id = 1256
# shape = (50, 6)
# window_id = 1257
# shape = (50, 6)
# window_id = 1258
# shape = (50, 6)
# window_id = 1259
# shape = (50, 6)
# window_id = 1260
# shape = (50, 6)
# window_id = 1261
# shape = (50, 6)
# window_id = 1262
# shape = (50, 6)
# window_id = 1263
# shape = (50, 6)
# window_id = 1264
# shape = (50, 6)
# window_id = 1265
# shape = (50, 6)
# window_id = 1266
# shape = (50, 6)
# window_id = 1267
# shape = (50, 6)
# window_id = 1268
# shape = (50, 6)
# window_id = 1269
# shape = (50, 6)
# window_id = 1270
# shape = (50, 6)
# window_id = 1271
# shape = (50, 6)
# window_id = 1272
# shape = (50, 6)
# window_id = 1273
# shape = (50, 6)
# window_id = 1274
# shape = (50, 6)
# window_id = 1275
# shape = (50, 6)
# window_id = 1276
# shape = (50, 6)
# window_id = 1277
# shape = (50, 6)
# window_id = 1278
# shape = (50, 6)
# window_id = 1279
# shape = (50, 6)
# window_id = 1280
# shape = (50, 6)
# window_id = 1281
# shape = (50, 6)
# window_id = 1282
# shape = (50, 6)
# window_id = 1283
# shape = (50, 6)
# window_id = 1284
# shape = (50, 6)
# window_id = 1285
# shape = (50, 6)
# window_id = 1286
# shape = (50, 6)
# window_id = 1287
# shape = (50, 6)
# window_id = 1288
# shape = (50, 6)
# window_id = 1289
# shape = (50, 6)
# window_id = 1290
# shape = (50, 6)
# window_id = 1291
# shape = (50, 6)
# window_id = 1292
# shape = (50, 6)
# window_id = 1293
# shape = (50, 6)
# window_id = 1294
# shape = (50, 6)
# window_id = 1295
# shape = (50, 6)
# window_id = 1296
# shape = (50, 6)
# window_id = 1297
# shape = (50, 6)
# window_id = 1298
# shape = (50, 6)
# window_id = 1299
# shape = (50, 6)
# window_id = 1300
# shape = (50, 6)
# window_id = 1301
# shape = (50, 6)
# window_id = 1302
# shape = (50, 6)
# window_id = 1303
# shape = (50, 6)
# window_id = 1304
# shape = (50, 6)
# window_id = 1305
# shape = (50, 6)
# window_id = 1306
# shape = (50, 6)
# window_id = 1307
# shape = (50, 6)
# window_id = 1308
# shape = (50, 6)
# window_id = 1309
# shape = (50, 6)
# window_id = 1310
# shape = (50, 6)
# window_id = 1311
# shape = (50, 6)
# window_id = 1312
# shape = (50, 6)
# window_id = 1313
# shape = (50, 6)
# window_id = 1314
# shape = (50, 6)
# window_id = 1315
# shape = (50, 6)
# window_id = 1316
# shape = (50, 6)
# window_id = 1317
# shape = (50, 6)
# window_id = 1318
# shape = (50, 6)
# window_id = 1319
# shape = (50, 6)
# window_id = 1320
# shape = (50, 6)
# window_id = 1321
# shape = (50, 6)
# window_id = 1322
# shape = (50, 6)
# window_id = 1323
# shape = (50, 6)
# window_id = 1324
# shape = (50, 6)
# window_id = 1325
# shape = (50, 6)
# window_id = 1326
# shape = (50, 6)
# window_id = 1327
# shape = (50, 6)
# window_id = 1328
# shape = (50, 6)
# window_id = 1329
# shape = (50, 6)
# window_id = 1330
# shape = (50, 6)
# window_id = 1331
# shape = (50, 6)
# window_id = 1332
# shape = (50, 6)
# window_id = 1333
# shape = (50, 6)
# window_id = 1334
# shape = (50, 6)
# window_id = 1335
# shape = (50, 6)
# window_id = 1336
# shape = (50, 6)
# window_id = 1337
# shape = (50, 6)
# window_id = 1338
# shape = (50, 6)
# window_id = 1339
# shape = (50, 6)
# window_id = 1340
# shape = (50, 6)
# window_id = 1341
# shape = (50, 6)
# window_id = 1342
# shape = (50, 6)
# window_id = 1343
# shape = (50, 6)
# window_id = 1344
# shape = (50, 6)
# window_id = 1345
# shape = (50, 6)
# window_id = 1346
# shape = (50, 6)
# window_id = 1347
# shape = (50, 6)
# window_id = 1348
# shape = (50, 6)
# window_id = 1349
# shape = (50, 6)
# window_id = 1350
# shape = (50, 6)
# window_id = 1351
# shape = (50, 6)
# window_id = 1352
# shape = (50, 6)
# window_id = 1353
# shape = (50, 6)
# window_id = 1354
# shape = (50, 6)
# window_id = 1355
# shape = (50, 6)
# window_id = 1356
# shape = (50, 6)
# window_id = 1357
# shape = (50, 6)
# window_id = 1358
# shape = (50, 6)
# window_id = 1359
# shape = (50, 6)
# window_id = 1360
# shape = (50, 6)
# window_id = 1361
# shape = (50, 6)
# window_id = 1362
# shape = (50, 6)
# window_id = 1363
# shape = (50, 6)
# window_id = 1364
# shape = (50, 6)
# window_id = 1365
# shape = (50, 6)
# window_id = 1366
# shape = (50, 6)
# window_id = 1367
# shape = (50, 6)
# window_id = 1368
# shape = (50, 6)
# window_id = 1369
# shape = (50, 6)
# window_id = 1370
# shape = (50, 6)
# window_id = 1371
# shape = (50, 6)
# window_id = 1372
# shape = (50, 6)
# window_id = 1373
# shape = (50, 6)
# window_id = 1374
# shape = (50, 6)
# window_id = 1375
# shape = (50, 6)
# window_id = 1376
# shape = (50, 6)
# window_id = 1377
# shape = (50, 6)
# window_id = 1378
# shape = (50, 6)
# window_id = 1379
# shape = (50, 6)
# window_id = 1380
# shape = (50, 6)
# window_id = 1381
# shape = (50, 6)
# window_id = 1382
# shape = (50, 6)
# window_id = 1383
# shape = (50, 6)
# window_id = 1384
# shape = (50, 6)
# window_id = 1385
# shape = (50, 6)
# window_id = 1386
# shape = (50, 6)
# window_id = 1387
# shape = (50, 6)
# window_id = 1388
# shape = (50, 6)
# window_id = 1389
# shape = (50, 6)
# window_id = 1390
# shape = (50, 6)
# window_id = 1391
# shape = (50, 6)
# window_id = 1392
# shape = (50, 6)
# window_id = 1393
# shape = (50, 6)
# window_id = 1394
# shape = (50, 6)
# window_id = 1395
# shape = (50, 6)
# window_id = 1396
# shape = (50, 6)
# window_id = 1397
# shape = (50, 6)
# window_id = 1398
# shape = (50, 6)
# window_id = 1399
# shape = (50, 6)
# window_id = 1400
# shape = (50, 6)
# window_id = 1401
# shape = (50, 6)
# window_id = 1402
# shape = (50, 6)
# window_id = 1403
# shape = (50, 6)
# window_id = 1404
# shape = (50, 6)
# window_id = 1405
# shape = (50, 6)
# window_id = 1406
# shape = (50, 6)
# window_id = 1407
# shape = (50, 6)
# window_id = 1408
# shape = (50, 6)
# window_id = 1409
# shape = (50, 6)
# window_id = 1410
# shape = (50, 6)
# window_id = 1411
# shape = (50, 6)
# window_id = 1412
# shape = (50, 6)
# window_id = 1413
# shape = (50, 6)
# window_id = 1414
# shape = (50, 6)
# window_id = 1415
# shape = (50, 6)
# window_id = 1416
# shape = (50, 6)
# window_id = 1417
# shape = (50, 6)
# window_id = 1418
# shape = (50, 6)
# window_id = 1419
# shape = (50, 6)
# window_id = 1420
# shape = (50, 6)
# window_id = 1421
# shape = (50, 6)
# window_id = 1422
# shape = (50, 6)
# window_id = 1423
# shape = (50, 6)
# window_id = 1424
# shape = (50, 6)
# window_id = 1425
# shape = (50, 6)
# window_id = 1426
# shape = (50, 6)
# window_id = 1427
# shape = (50, 6)
# window_id = 1428
# shape = (50, 6)
# window_id = 1429
# shape = (50, 6)
# window_id = 1430
# shape = (50, 6)
# window_id = 1431
# shape = (50, 6)
# window_id = 1432
# shape = (50, 6)
# window_id = 1433
# shape = (50, 6)
# window_id = 1434
# shape = (50, 6)
# window_id = 1435
# shape = (50, 6)
# window_id = 1436
# shape = (50, 6)
# window_id = 1437
# shape = (50, 6)
# window_id = 1438
# shape = (50, 6)
# window_id = 1439
# shape = (50, 6)
# window_id = 1440
# shape = (50, 6)
# window_id = 1441
# shape = (50, 6)
# window_id = 1442
# shape = (50, 6)
# window_id = 1443
# shape = (50, 6)
# window_id = 1444
# shape = (50, 6)
# window_id = 1445
# shape = (50, 6)
# window_id = 1446
# shape = (50, 6)
# window_id = 1447
# shape = (50, 6)
# window_id = 1448
# shape = (50, 6)
# window_id = 1449
# shape = (50, 6)
# window_id = 1450
# shape = (50, 6)
# window_id = 1451
# shape = (50, 6)
# window_id = 1452
# shape = (50, 6)
# window_id = 1453
# shape = (50, 6)
# window_id = 1454
# shape = (50, 6)
# window_id = 1455
# shape = (50, 6)
# window_id = 1456
# shape = (50, 6)
# window_id = 1457
# shape = (50, 6)
# window_id = 1458
# shape = (50, 6)
# window_id = 1459
# shape = (50, 6)
# window_id = 1460
# shape = (50, 6)
# window_id = 1461
# shape = (50, 6)
# window_id = 1462
# shape = (50, 6)
# window_id = 1463
# shape = (50, 6)
# window_id = 1464
# shape = (50, 6)
# window_id = 1465
# shape = (50, 6)
# window_id = 1466
# shape = (50, 6)
# window_id = 1467
# shape = (50, 6)
# window_id = 1468
# shape = (50, 6)
# window_id = 1469
# shape = (50, 6)
# window_id = 1470
# shape = (50, 6)
# window_id = 1471
# shape = (50, 6)
# window_id = 1472
# shape = (50, 6)
# window_id = 1473
# shape = (50, 6)
# window_id = 1474
# shape = (50, 6)
# window_id = 1475
# shape = (50, 6)
# window_id = 1476
# shape = (50, 6)
# window_id = 1477
# shape = (50, 6)
# window_id = 1478
# shape = (50, 6)
# window_id = 1479
# shape = (50, 6)
# window_id = 1480
# shape = (50, 6)
# window_id = 1481
# shape = (50, 6)
# window_id = 1482
# shape = (50, 6)
# window_id = 1483
# shape = (50, 6)
# window_id = 1484
# shape = (50, 6)
# window_id = 1485
# shape = (50, 6)
# window_id = 1486
# shape = (50, 6)
# window_id = 1487
# shape = (50, 6)
# ...
# shape = (50, 6)
# window_id = 2343
# shape = (50, 6)
# window_id = 2344
# shape = (50, 6)
# window_id = 2345
# shape = (50, 6)
# window_id = 2346
# shape = (50, 6)
# window_id = 2347
# shape = (50, 6)
# window_id = 2348
# shape = (50, 6)
# window_id = 2349
# shape = (50, 6)
# window_id = 2350
# shape = (50, 6)
# window_id = 2351
# shape = (50, 6)
# window_id = 2352
# shape = (50, 6)
# window_id = 2353
# shape = (50, 6)
# window_id = 2354
# shape = (50, 6)
# window_id = 2355
# shape = (50, 6)
# window_id = 2356
# shape = (50, 6)
# window_id = 2357
# shape = (50, 6)
# window_id = 2358
# shape = (50, 6)
# window_id = 2359
# shape = (50, 6)
# window_id = 2360
# shape = (50, 6)
# window_id = 2361
# shape = (50, 6)
# window_id = 2362
# shape = (50, 6)
# window_id = 2363
# shape = (50, 6)
# window_id = 2364
# shape = (50, 6)
# window_id = 2365
# shape = (50, 6)
# window_id = 2366
# shape = (50, 6)
# window_id = 2367
# shape = (50, 6)
# window_id = 2368
# shape = (50, 6)
# window_id = 2369
# shape = (50, 6)
# window_id = 2370
# shape = (50, 6)
# window_id = 2371
# shape = (50, 6)
# window_id = 2372
# shape = (50, 6)
# window_id = 2373
# shape = (50, 6)
# window_id = 2374
# shape = (50, 6)
# window_id = 2375
# shape = (50, 6)
# window_id = 2376
# shape = (50, 6)
# window_id = 2377
# shape = (50, 6)
# window_id = 2378
# shape = (50, 6)
# window_id = 2379
# shape = (50, 6)
# window_id = 2380
# shape = (50, 6)
# window_id = 2381
# shape = (50, 6)
# window_id = 2382
# shape = (50, 6)
# window_id = 2383
# shape = (50, 6)
# window_id = 2384
# shape = (50, 6)
# window_id = 2385
# shape = (50, 6)
# window_id = 2386
# shape = (50, 6)
# window_id = 2387
# shape = (50, 6)
# window_id = 2388
# shape = (50, 6)
# window_id = 2389
# shape = (50, 6)
# window_id = 2390
# shape = (50, 6)
# window_id = 2391
# shape = (50, 6)
# window_id = 2392
# shape = (50, 6)
# window_id = 2393
# shape = (50, 6)
# window_id = 2394
# shape = (50, 6)
# window_id = 2395
# shape = (50, 6)
# window_id = 2396
# shape = (50, 6)
# window_id = 2397
# shape = (50, 6)
# window_id = 2398
# shape = (50, 6)
# window_id = 2399
# shape = (50, 6)
# window_id = 2400
# shape = (50, 6)
# window_id = 2401
# shape = (50, 6)
# window_id = 2402
# shape = (50, 6)
# window_id = 2403
# shape = (50, 6)
# window_id = 2404
# shape = (50, 6)
# window_id = 2405
# shape = (50, 6)
# window_id = 2406
# shape = (50, 6)
# window_id = 2407
# shape = (50, 6)
# window_id = 2408
# shape = (50, 6)
# window_id = 2409
# shape = (50, 6)
# window_id = 2410
# shape = (50, 6)
# window_id = 2411
# shape = (50, 6)
# window_id = 2412
# shape = (50, 6)
# window_id = 2413
# shape = (50, 6)
# window_id = 2414
# shape = (50, 6)
# window_id = 2415
# shape = (50, 6)
# window_id = 2416
# shape = (50, 6)
# window_id = 2417
# shape = (50, 6)
# window_id = 2418
# shape = (50, 6)
# window_id = 2419
# shape = (50, 6)
# window_id = 2420
# shape = (50, 6)
# window_id = 2421
# shape = (50, 6)
# window_id = 2422
# shape = (50, 6)
# window_id = 2423
# shape = (50, 6)
# window_id = 2424
# shape = (50, 6)
# window_id = 2425
# shape = (50, 6)
# window_id = 2426
# shape = (50, 6)
# window_id = 2427
# shape = (50, 6)
# window_id = 2428
# shape = (50, 6)
# window_id = 2429
# shape = (50, 6)
# window_id = 2430
# shape = (50, 6)
# window_id = 2431
# shape = (50, 6)
# window_id = 2432
# shape = (50, 6)
# window_id = 2433
# shape = (50, 6)
# window_id = 2434
# shape = (50, 6)
# window_id = 2435
# shape = (50, 6)
# window_id = 2436
# shape = (50, 6)
# window_id = 2437
# shape = (50, 6)
# window_id = 2438
# shape = (50, 6)
# window_id = 2439
# shape = (50, 6)
# window_id = 2440
# shape = (50, 6)
# window_id = 2441
# shape = (50, 6)
# window_id = 2442
# shape = (50, 6)
# window_id = 2443
# shape = (50, 6)
# window_id = 2444
# shape = (50, 6)
# window_id = 2445
# shape = (50, 6)
# window_id = 2446
# shape = (50, 6)
# window_id = 2447
# shape = (50, 6)
# window_id = 2448
# shape = (50, 6)
# window_id = 2449
# shape = (50, 6)
# window_id = 2450
# shape = (50, 6)
# window_id = 2451
# shape = (50, 6)
# window_id = 2452
# shape = (50, 6)
# window_id = 2453
# shape = (50, 6)
# window_id = 2454
# shape = (50, 6)
# window_id = 2455
# shape = (50, 6)
# window_id = 2456
# shape = (50, 6)
# window_id = 2457
# shape = (50, 6)
# window_id = 2458
# shape = (50, 6)
# window_id = 2459
# shape = (50, 6)
# window_id = 2460
# shape = (50, 6)
# window_id = 2461
# shape = (50, 6)
# window_id = 2462
# shape = (50, 6)
# window_id = 2463
# shape = (50, 6)
# window_id = 2464
# shape = (50, 6)
# window_id = 2465
# shape = (50, 6)
# window_id = 2466
# shape = (50, 6)
# window_id = 2467
# shape = (50, 6)
# window_id = 2468
# shape = (50, 6)
# window_id = 2469
# shape = (50, 6)
# window_id = 2470
# shape = (50, 6)
# window_id = 2471
# shape = (50, 6)
# window_id = 2472
# shape = (50, 6)
# window_id = 2473
# shape = (50, 6)
# window_id = 2474
# shape = (50, 6)
# window_id = 2475
# shape = (50, 6)
# window_id = 2476
# shape = (50, 6)
# window_id = 2477
# shape = (50, 6)
# window_id = 2478
# shape = (50, 6)
# window_id = 2479
# shape = (50, 6)
# window_id = 2480
# shape = (50, 6)
# window_id = 2481
# shape = (50, 6)
# window_id = 2482
# shape = (50, 6)
# window_id = 2483
# shape = (50, 6)
# window_id = 2484
# shape = (50, 6)
# window_id = 2485
# shape = (50, 6)
# window_id = 2486
# shape = (50, 6)
# window_id = 2487
# shape = (50, 6)
# window_id = 2488
# shape = (50, 6)
# window_id = 2489
# shape = (50, 6)
# window_id = 2490
# shape = (50, 6)
# window_id = 2491
# shape = (50, 6)
# window_id = 2492
# shape = (50, 6)
# window_id = 2493
# shape = (50, 6)
# window_id = 2494
# shape = (50, 6)
# window_id = 2495
# shape = (50, 6)
# window_id = 2496
# shape = (50, 6)
# window_id = 2497
# shape = (50, 6)
# window_id = 2498
# shape = (50, 6)
# window_id = 2499
# shape = (50, 6)
# window_id = 2500
# shape = (50, 6)
# window_id = 2501
# shape = (50, 6)
# window_id = 2502
# shape = (50, 6)
# window_id = 2503
# shape = (50, 6)
# window_id = 2504
# shape = (50, 6)
# window_id = 2505
# shape = (50, 6)
# window_id = 2506
# shape = (50, 6)
# window_id = 2507
# shape = (50, 6)
# window_id = 2508
# shape = (50, 6)
# window_id = 2509
# shape = (50, 6)
# window_id = 2510
# shape = (50, 6)
# window_id = 2511
# shape = (50, 6)
# window_id = 2512
# shape = (50, 6)
# window_id = 2513
# shape = (50, 6)
# window_id = 2514
# shape = (50, 6)
# window_id = 2515
# shape = (50, 6)
# window_id = 2516
# shape = (50, 6)
# window_id = 2517
# shape = (50, 6)
# window_id = 2518
# shape = (50, 6)
# window_id = 2519
# shape = (50, 6)
# window_id = 2520
# shape = (50, 6)
# window_id = 2521
# shape = (50, 6)
# window_id = 2522
# shape = (50, 6)
# window_id = 2523
# shape = (50, 6)
# window_id = 2524
# shape = (50, 6)
# window_id = 2525
# shape = (50, 6)
# window_id = 2526
# shape = (50, 6)
# window_id = 2527
# shape = (50, 6)
# window_id = 2528
# shape = (50, 6)
# window_id = 2529
# shape = (50, 6)
# window_id = 2530
# shape = (50, 6)
# window_id = 2531
# shape = (50, 6)
# window_id = 2532
# shape = (50, 6)
# window_id = 2533
# shape = (50, 6)
# window_id = 2534
# shape = (50, 6)
# window_id = 2535
# shape = (50, 6)
# window_id = 2536
# shape = (50, 6)
# window_id = 2537
# shape = (50, 6)
# window_id = 2538
# shape = (50, 6)
# window_id = 2539
# shape = (50, 6)
# window_id = 2540
# shape = (50, 6)
# window_id = 2541
# shape = (50, 6)
# window_id = 2542
# shape = (50, 6)
# window_id = 2543
# shape = (50, 6)
# window_id = 2544
# shape = (50, 6)
# window_id = 2545
# shape = (50, 6)
# window_id = 2546
# shape = (50, 6)
# window_id = 2547
# shape = (50, 6)
# window_id = 2548
# shape = (50, 6)
# window_id = 2549
# shape = (50, 6)
# window_id = 2550
# shape = (50, 6)
# window_id = 2551
# shape = (50, 6)
# window_id = 2552
# shape = (50, 6)
# window_id = 2553
# shape = (50, 6)
# window_id = 2554
# shape = (50, 6)
# window_id = 2555
# shape = (50, 6)
# window_id = 2556
# shape = (50, 6)
# window_id = 2557
# shape = (50, 6)
# window_id = 2558
# shape = (50, 6)
# window_id = 2559
# shape = (50, 6)
# window_id = 2560
# shape = (50, 6)
# window_id = 2561
# shape = (50, 6)
# window_id = 2562
# shape = (50, 6)
# window_id = 2563
# shape = (50, 6)
# window_id = 2564
# shape = (50, 6)
# window_id = 2565
# shape = (50, 6)
# window_id = 2566
# shape = (50, 6)
# window_id = 2567
# shape = (50, 6)
# window_id = 2568
# shape = (50, 6)
# window_id = 2569
# shape = (50, 6)
# window_id = 2570
# shape = (50, 6)
# window_id = 2571
# shape = (50, 6)
# window_id = 2572
# shape = (50, 6)
# window_id = 2573
# shape = (50, 6)
# window_id = 2574
# shape = (50, 6)
# window_id = 2575
# shape = (50, 6)
# window_id = 2576
# shape = (50, 6)
# window_id = 2577
# shape = (50, 6)
# window_id = 2578
# shape = (50, 6)
# window_id = 2579
# shape = (50, 6)
# window_id = 2580
# shape = (50, 6)
# window_id = 2581
# shape = (50, 6)
# window_id = 2582
# shape = (50, 6)
# window_id = 2583
# shape = (50, 6)
# window_id = 2584
# shape = (50, 6)
# window_id = 2585
# shape = (50, 6)
# window_id = 2586
# shape = (50, 6)
# window_id = 2587
# shape = (50, 6)
# window_id = 2588
# shape = (50, 6)
# window_id = 2589
# shape = (50, 6)
# window_id = 2590
# shape = (50, 6)
# window_id = 2591
# shape = (50, 6)
# window_id = 2592
# shape = (50, 6)
# window_id = 2593
# shape = (50, 6)
# window_id = 2594
# shape = (50, 6)
# window_id = 2595
# shape = (50, 6)
# window_id = 2596
# shape = (50, 6)
# window_id = 2597
# shape = (50, 6)
# window_id = 2598
# shape = (50, 6)
# window_id = 2599
# shape = (50, 6)
# window_id = 2600
# shape = (50, 6)
# window_id = 2601
# shape = (50, 6)
# window_id = 2602
# shape = (50, 6)
# window_id = 2603
# shape = (50, 6)
# window_id = 2604
# shape = (50, 6)
# window_id = 2605
# shape = (50, 6)
# window_id = 2606
# shape = (50, 6)
# window_id = 2607
# shape = (50, 6)
# window_id = 2608
# shape = (50, 6)
# window_id = 2609
# shape = (50, 6)
# window_id = 2610
# shape = (50, 6)
# window_id = 2611
# shape = (50, 6)
# window_id = 2612
# shape = (50, 6)
# window_id = 2613
# shape = (50, 6)
# window_id = 2614
# shape = (50, 6)
# window_id = 2615
# shape = (50, 6)
# window_id = 2616
# shape = (50, 6)
# window_id = 2617
# shape = (50, 6)
# window_id = 2618
# shape = (50, 6)
# window_id = 2619
# shape = (50, 6)
# window_id = 2620
# shape = (50, 6)
# window_id = 2621
# shape = (50, 6)
# window_id = 2622
# shape = (50, 6)
# window_id = 2623
# shape = (50, 6)
# window_id = 2624
# shape = (50, 6)
# window_id = 2625
# shape = (50, 6)
# window_id = 2626
# shape = (50, 6)
# window_id = 2627
# shape = (50, 6)
# window_id = 2628
# shape = (50, 6)
# window_id = 2629
# shape = (50, 6)
# window_id = 2630
# shape = (50, 6)
# window_id = 2631
# shape = (50, 6)
# window_id = 2632
# shape = (50, 6)
# window_id = 2633
# shape = (50, 6)
# window_id = 2634
# shape = (50, 6)
# window_id = 2635
# shape = (50, 6)
# window_id = 2636
# shape = (50, 6)
# window_id = 2637
# shape = (50, 6)
# window_id = 2638
# shape = (50, 6)
# window_id = 2639
# shape = (50, 6)
# window_id = 2640
# shape = (50, 6)
# window_id = 2641
# shape = (50, 6)
# window_id = 2642
# shape = (50, 6)
# window_id = 2643
# shape = (50, 6)
# window_id = 2644
# shape = (50, 6)
# window_id = 2645
# shape = (50, 6)
# window_id = 2646
# shape = (50, 6)
# window_id = 2647
# shape = (50, 6)
# window_id = 2648
# shape = (50, 6)
# window_id = 2649
# shape = (50, 6)
# window_id = 2650
# shape = (50, 6)
# window_id = 2651
# shape = (50, 6)
# window_id = 2652
# shape = (50, 6)
# window_id = 2653
# shape = (50, 6)
# window_id = 2654
# shape = (50, 6)
# window_id = 2655
# shape = (50, 6)
# window_id = 2656
# shape = (50, 6)
# window_id = 2657
# shape = (50, 6)
# window_id = 2658
# shape = (50, 6)
# window_id = 2659
# shape = (50, 6)
# window_id = 2660
# shape = (50, 6)
# window_id = 2661
# shape = (50, 6)
# window_id = 2662
# shape = (50, 6)
# window_id = 2663
# shape = (50, 6)
# window_id = 2664
# shape = (50, 6)
# window_id = 2665
# shape = (50, 6)
# window_id = 2666
# shape = (50, 6)
# window_id = 2667
# shape = (50, 6)
# window_id = 2668
# shape = (50, 6)
# window_id = 2669
# shape = (50, 6)
# window_id = 2670
# shape = (50, 6)
# window_id = 2671
# shape = (50, 6)
# window_id = 2672
# shape = (50, 6)
# window_id = 2673
# shape = (50, 6)
# window_id = 2674
# shape = (50, 6)
# window_id = 2675
# shape = (50, 6)
# window_id = 2676
# shape = (50, 6)
# window_id = 2677
# shape = (50, 6)
# window_id = 2678
# shape = (50, 6)
# window_id = 2679
# shape = (50, 6)
# window_id = 2680
# shape = (50, 6)
# window_id = 2681
# shape = (50, 6)
# window_id = 2682
# shape = (50, 6)
# window_id = 2683
# shape = (50, 6)
# window_id = 2684
# shape = (50, 6)
# window_id = 2685
# shape = (50, 6)
# window_id = 2686
# shape = (50, 6)
# window_id = 2687
# shape = (50, 6)
# window_id = 2688
# shape = (50, 6)
# window_id = 2689
# shape = (50, 6)
# window_id = 2690
# shape = (50, 6)
# window_id = 2691
# shape = (50, 6)
# window_id = 2692
# shape = (50, 6)
# window_id = 2693
# shape = (50, 6)
# window_id = 2694
# shape = (50, 6)
# window_id = 2695
# shape = (50, 6)
# window_id = 2696
# shape = (50, 6)
# window_id = 2697
# shape = (50, 6)
# window_id = 2698
# shape = (50, 6)
# window_id = 2699
# shape = (50, 6)
# window_id = 2700
# shape = (50, 6)
# window_id = 2701
# shape = (50, 6)
# window_id = 2702
# shape = (50, 6)
# window_id = 2703
# shape = (50, 6)
# window_id = 2704
# shape = (50, 6)
# window_id = 2705
# shape = (50, 6)
# window_id = 2706
# shape = (50, 6)
# window_id = 2707
# shape = (50, 6)
# window_id = 2708
# shape = (50, 6)
# window_id = 2709
# shape = (50, 6)
# window_id = 2710
# shape = (50, 6)
# window_id = 2711
# shape = (50, 6)
# window_id = 2712
# shape = (50, 6)
# window_id = 2713
# shape = (50, 6)
# window_id = 2714
# shape = (50, 6)
# window_id = 2715
# shape = (50, 6)
# window_id = 2716
# shape = (50, 6)
# window_id = 2717
# shape = (50, 6)
# window_id = 2718
# shape = (50, 6)
# window_id = 2719
# shape = (50, 6)
# window_id = 2720
# shape = (50, 6)
# window_id = 2721
# shape = (50, 6)
# window_id = 2722
# shape = (50, 6)
# window_id = 2723
# shape = (50, 6)
# window_id = 2724
# shape = (50, 6)
# window_id = 2725
# shape = (50, 6)
# window_id = 2726
# shape = (50, 6)
# window_id = 2727
# shape = (50, 6)
# window_id = 2728
# shape = (50, 6)
# window_id = 2729
# shape = (50, 6)
# window_id = 2730
# shape = (50, 6)
# window_id = 2731
# shape = (50, 6)
# window_id = 2732
# shape = (50, 6)
# window_id = 2733
# shape = (50, 6)
# window_id = 2734
# shape = (50, 6)
# window_id = 2735
# shape = (50, 6)
# window_id = 2736
# shape = (50, 6)
# window_id = 2737
# shape = (50, 6)
# window_id = 2738
# shape = (50, 6)
# window_id = 2739
# shape = (50, 6)
# window_id = 2740
# shape = (50, 6)
# window_id = 2741
# shape = (50, 6)
# window_id = 2742
# shape = (50, 6)
# window_id = 2743
# shape = (50, 6)
# window_id = 2744
# shape = (50, 6)
# window_id = 2745
# shape = (50, 6)
# window_id = 2746
# shape = (50, 6)
# window_id = 2747
# shape = (50, 6)
# window_id = 2748
# shape = (50, 6)
# window_id = 2749
# shape = (50, 6)
# window_id = 2750
# shape = (50, 6)
# window_id = 2751
# shape = (50, 6)
# window_id = 2752
# shape = (50, 6)
# window_id = 2753
# shape = (50, 6)
# window_id = 2754
# shape = (50, 6)
# window_id = 2755
# shape = (50, 6)
# window_id = 2756
# shape = (50, 6)
# window_id = 2757
# shape = (50, 6)
# window_id = 2758
# shape = (50, 6)
# window_id = 2759
# shape = (50, 6)
# window_id = 2760
# shape = (50, 6)
# window_id = 2761
# shape = (50, 6)
# window_id = 2762
# shape = (50, 6)
# window_id = 2763
# shape = (50, 6)
# window_id = 2764
# shape = (50, 6)
# window_id = 2765
# shape = (50, 6)
# window_id = 2766
# shape = (50, 6)
# window_id = 2767
# shape = (50, 6)
# window_id = 2768
# shape = (50, 6)
# window_id = 2769
# shape = (50, 6)
# window_id = 2770
# shape = (50, 6)
# window_id = 2771
# shape = (50, 6)
# window_id = 2772
# shape = (50, 6)
# window_id = 2773
# shape = (50, 6)
# window_id = 2774
# shape = (50, 6)
# window_id = 2775
# shape = (50, 6)
# window_id = 2776
# shape = (50, 6)
# window_id = 2777
# shape = (50, 6)
# window_id = 2778
# shape = (50, 6)
# window_id = 2779
# shape = (50, 6)
# window_id = 2780
# shape = (50, 6)
# window_id = 2781
# shape = (50, 6)
# window_id = 2782
# shape = (50, 6)
# window_id = 2783
# shape = (50, 6)
# window_id = 2784
# shape = (50, 6)
# window_id = 2785
# shape = (50, 6)
# window_id = 2786
# shape = (50, 6)
# window_id = 2787
# shape = (50, 6)
# window_id = 2788
# shape = (50, 6)
# window_id = 2789
# shape = (50, 6)
# window_id = 2790
# shape = (50, 6)
# window_id = 2791
# shape = (50, 6)
# window_id = 2792
# shape = (50, 6)
# window_id = 2793
# shape = (50, 6)
# window_id = 2794
# shape = (50, 6)
# window_id = 2795
# shape = (50, 6)
# window_id = 2796
# shape = (50, 6)
# window_id = 2797
# shape = (50, 6)
# window_id = 2798
# shape = (50, 6)
# window_id = 2799
# shape = (50, 6)
# window_id = 2800
# shape = (50, 6)
# window_id = 2801
# shape = (50, 6)
# window_id = 2802
# shape = (50, 6)
# window_id = 2803
# shape = (50, 6)
# window_id = 2804
# shape = (50, 6)
# window_id = 2805
# shape = (50, 6)
# window_id = 2806
# shape = (50, 6)
# window_id = 2807
# shape = (50, 6)
# window_id = 2808
# shape = (50, 6)
# window_id = 2809
# shape = (50, 6)
# window_id = 2810
# shape = (50, 6)
# window_id = 2811
# shape = (50, 6)
# window_id = 2812
# shape = (50, 6)
# window_id = 2813
# shape = (50, 6)
# window_id = 2814
# shape = (50, 6)
# window_id = 2815
# shape = (50, 6)
# window_id = 2816
# shape = (50, 6)
# window_id = 2817
# shape = (50, 6)
# window_id = 2818
# shape = (50, 6)
# window_id = 2819
# shape = (50, 6)
# window_id = 2820
# shape = (50, 6)
# window_id = 2821
# shape = (50, 6)
# window_id = 2822
# shape = (50, 6)
# window_id = 2823
# shape = (50, 6)
# window_id = 2824
# shape = (50, 6)
# window_id = 2825
# shape = (50, 6)
# window_id = 2826
# shape = (50, 6)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics = ['accuracy'])

# %%
model.fit(X_train, y_train, batch_size=32, epochs=1)
# Out:
# Train on 25676 samples
# Epoch 1/10
# 25676/25676 [==============================] - 81s 3ms/sample - loss: 0.7943 - accuracy: 0.7016
# Epoch 2/10
# 25676/25676 [==============================] - 77s 3ms/sample - loss: 0.5791 - accuracy: 0.7720
# Epoch 3/10
# 25676/25676 [==============================] - 77s 3ms/sample - loss: 0.5212 - accuracy: 0.7884
# Epoch 4/10
# 25676/25676 [==============================] - 74s 3ms/sample - loss: 0.4945 - accuracy: 0.7994
# Epoch 5/10
# 25676/25676 [==============================] - 79s 3ms/sample - loss: 0.4724 - accuracy: 0.8071
# Epoch 6/10
# 25676/25676 [==============================] - 74s 3ms/sample - loss: 0.4595 - accuracy: 0.8107
# Epoch 7/10
# 25676/25676 [==============================] - 67s 3ms/sample - loss: 0.4460 - accuracy: 0.8129
# Epoch 8/10
# 25676/25676 [==============================] - 74s 3ms/sample - loss: 0.4338 - accuracy: 0.8185
# Epoch 9/10
# 25676/25676 [==============================] - 82s 3ms/sample - loss: 0.4201 - accuracy: 0.8252
# Epoch 10/10
# 25676/25676 [==============================] - 74s 3ms/sample - loss: 0.4140 - accuracy: 0.8266

# %%
labels_list = ["Standing", "Climbing stairs", "Descending stairs", "Desk work", "Lying down left", "Lying down on back", "Lying down on stomach", "Lying down right", "Running", "Sitting bent backward", "Sitting bent forward", "Sitting", "Walking at normal speed","Movement"]

# %%
(_,accuracy) = model.evaluate(X_test, y_test)
accuracy = accuracy * 100.0
print(accuracy)

y_pred_ohe = model.predict(X_test)
y_pred_labels = np.argmax(y_pred_ohe, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

print("*" * 80)
print("Classification report")
print("*" * 80)
print(classification_report(y_true_labels, y_pred_labels))

confusion_matrix = metrics.confusion_matrix(y_true_labels, y_pred_labels)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels=["Climbing stairs", "Descending stairs", "Desk work", "Lying down left", "Lying down on back", "Lying down on stomach", "Lying down right", "Running", "Sitting", "Sitting bent backward", "Sitting bent forward", "Standing", "Walking at normal speed"])
cm_display.plot()
plt.show()
# Out:
# 3277/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# 75.92310309410095
# ********************************************************************************
# Classification report
# ********************************************************************************
#               precision    recall  f1-score   support
#
#            0       1.00      0.25      0.40       234
#            1       0.73      0.75      0.74       234
#            2       0.91      0.96      0.93       233
#            3       0.26      0.64      0.37       233
#            4       1.00      1.00      1.00       235
#            5       0.87      1.00      0.93       234
#            6       1.00      1.00      1.00       235
#            7       0.96      1.00      0.98       235
#            8       0.96      0.95      0.96       233
#            9       0.63      0.45      0.52       235
#           10       0.84      0.96      0.89       233
#           11       0.00      0.00      0.00       234
#           12       0.95      0.77      0.85       236
#           13       0.66      0.91      0.77       233
#
#     accuracy                           0.76      3277
#    macro avg       0.77      0.76      0.74      3277
# weighted avg       0.77      0.76      0.74      3277
# /Users/Nandini/opt/anaconda3/envs/pdiotnew/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Nandini/opt/anaconda3/envs/pdiotnew/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Nandini/opt/anaconda3/envs/pdiotnew/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/bj/sp7hbb713f7b8wzpdh_c9sb40000gn/T/ipykernel_58745/2043407360.py in <module>
#      14 confusion_matrix = metrics.confusion_matrix(y_true_labels, y_pred_labels)
#      15 cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels=["Climbing stairs", "Descending stairs", "Desk work", "Lying down left", "Lying down on back", "Lying down on stomach", "Lying down right", "Running", "Sitting", "Sitting bent backward", "Sitting bent forward", "Standing", "Walking at normal speed"])
# ---> 16 cm_display.plot()
#      17 plt.show()
#
# ~/opt/anaconda3/envs/pdiotnew/lib/python3.7/site-packages/sklearn/metrics/_plot/confusion_matrix.py in plot(self, include_values, cmap, xticks_rotation, values_format, ax, colorbar)
#     167             yticklabels=display_labels,
#     168             ylabel="True label",
# --> 169             xlabel="Predicted label",
#     170         )
#     171
#
# ~/opt/anaconda3/envs/pdiotnew/lib/python3.7/site-packages/matplotlib/artist.py in <lambda>(self, **kwargs)
#     114             return
#     115
# --> 116         cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     117         cls.set.__name__ = "set"
#     118         cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# ~/opt/anaconda3/envs/pdiotnew/lib/python3.7/site-packages/matplotlib/artist.py in set(self, **kwargs)
#    1162         # module.
#    1163         kwargs = cbook.normalize_kwargs(kwargs, self)
# -> 1164         return self.update(kwargs)
#    1165
#    1166     @contextlib.contextmanager
#
# ~/opt/anaconda3/envs/pdiotnew/lib/python3.7/site-packages/matplotlib/artist.py in update(self, props)
#    1064                         raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                              f"has no property {k!r}")
# -> 1066                     ret.append(func(v))
#    1067         if ret:
#    1068             self.pchanged()
#
# ~/opt/anaconda3/envs/pdiotnew/lib/python3.7/site-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      73
#      74         def wrapper(self, *args, **kwargs):
# ---> 75             return get_method(self)(*args, **kwargs)
#      76
#      77         wrapper.__module__ = owner.__module__
#
# ~/opt/anaconda3/envs/pdiotnew/lib/python3.7/site-packages/matplotlib/axis.py in _set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1796         if fontdict is not None:
#    1797             kwargs.update(fontdict)
# -> 1798         return self.set_ticklabels(labels, minor=minor, **kwargs)
#    1799
#    1800     def _set_tick_locations(self, ticks, *, minor=False):
#
# ~/opt/anaconda3/envs/pdiotnew/lib/python3.7/site-packages/matplotlib/axis.py in set_ticklabels(self, ticklabels, minor, **kwargs)
#    1719             if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
#    1720                 raise ValueError(
# -> 1721                     "The number of FixedLocator locations"
#    1722                     f" ({len(locator.locs)}), usually from a call to"
#    1723                     " set_ticks, does not match"
#
# ValueError: The number of FixedLocator locations (14), usually from a call to set_ticks, does not match the number of ticklabels (13).

# %%
(_,accuracy) = model.evaluate(X_validate, y_validate)
accuracy = accuracy * 100.0
print(accuracy)

y_pred_ohe = model.predict(X_validate)
y_pred_labels = np.argmax(y_pred_ohe, axis=1)
y_true_labels = np.argmax(y_validate, axis=1)

print("*" * 80)
print("Classification report")
print("*" * 80)
print(classification_report(y_true_labels, y_pred_labels))

confusion_matrix = metrics.confusion_matrix(y_true_labels, y_pred_labels)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels=labels_list)
cm_display.plot()
plt.show()
# Out:
# 2827/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# 69.89741921424866
# ********************************************************************************
# Classification report
# ********************************************************************************
#               precision    recall  f1-score   support
#
#            0       0.48      0.13      0.21       204
#            1       0.61      0.80      0.70       204
#            2       0.96      0.70      0.81       204
#            3       0.16      0.33      0.22       204
#            4       1.00      1.00      1.00       176
#            5       0.78      1.00      0.87       204
#            6       1.00      0.86      0.92       204
#            7       0.88      1.00      0.94       204
#            8       0.99      0.98      0.99       203
#            9       0.68      0.57      0.62       204
#           10       0.56      0.87      0.68       204
#           11       0.54      0.14      0.22       204
#           12       0.90      0.60      0.72       204
#           13       0.79      0.84      0.82       204
#
#     accuracy                           0.70      2827
#    macro avg       0.74      0.70      0.69      2827
# weighted avg       0.74      0.70      0.69      2827

# %%
keras_file = "linear.h5"
tf.keras.models.save_model(
  model,
  keras_file
)

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tfmodel = converter.convert()
open("har_classifier.tflite","wb").write(tfmodel)
